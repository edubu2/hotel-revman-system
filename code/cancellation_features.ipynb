# %%
import pandas as pd
import numpy as np
import datetime

# %%
pd.options.display.max_rows = 60
pd.options.display.max_columns = 60

# %%
h1_res = pd.read_pickle("pickle/h1_res.pick")
h2_res = pd.read_pickle("pickle/h2_res.pick")
h1_dbd = pd.read_pickle("pickle/h1_dbd.pick")
h2_dbd = pd.read_pickle("pickle/h2_dbd.pick")

# %%
h1_res.head(5)
# Out:
#    ResNum  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0       0           0       342             2015             July
# 1       1           0       737             2015             July
# 2       2           0         7             2015             July
# 3       3           0        13             2015             July
# 4       4           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 0                  0       2         0       0  BB            PRT
# ...

# %% [markdown]
# ## Get all variables in `hx_res` ready for modeling

# %%
h1_res.head(3)
# Out:
#    ResNum  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0       0           0       342             2015             July
# 1       1           0       737             2015             July
# 2       2           0         7             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 0                  0       2         0       0  BB            PRT
# 1                  0       2         0       0  BB            PRT
# 2                  1       1         0       0  BB            GBR
#
#   MarketSegment DistributionChannel  IsRepeatedGuest  PreviousCancellations  \
# ...

# %%
mask = h1_res.ADR == 0
h1_res[mask]
# Out:
#        ResNum  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0           0       342             2015             July
# 1           1           0       737             2015             July
# 125       125           0        32             2015             July
# 167       167           0       111             2015             July
# 168       168           0         0             2015             July
# ...       ...         ...       ...              ...              ...
# 39427   39427           0         6             2017           August
# 39527   39527           0         0             2017           August
# 39585   39585           0         4             2017           August
# 39852   39852           0         0             2017           August
# 40016   40016           0        87             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# ...

# %%
h1_res.Country.value_counts().head(20)
# Out:
# PRT    17630
# GBR     6814
# ESP     3957
# IRL     2166
# FRA     1611
# DEU     1203
# CN       710
# NLD      514
# USA      479
# ITA      459
# BEL      448
# CHE      435
# BRA      430
# POL      333
# SWE      304
# AUT      210
# RUS      189
# ROU      177
# FIN      151
# CHN      134
# Name: Country, dtype: int64

# %%
h1_res.RequiredCarParkingSpaces.value_counts()
# Out:
# 0    34570
# 1     5462
# 2       25
# 8        2
# 3        1
# Name: RequiredCarParkingSpaces, dtype: int64

# %%
h1_res.columns
# Out:
# Index(['ResNum', 'IsCanceled', 'LeadTime', 'ArrivalDateYear',
#        'ArrivalDateMonth', 'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatus', 'ReservationStatusDate',
#        'ArrivalDate', 'LOS', 'PreviousBookings', 'ResMadeDate', 'NumPeople',
#        'CT_is_grp', 'CT_is_trn', 'CT_is_trnP', 'RS_No-Show', 'MS_Corporate',
#        'MS_Direct', 'MS_Groups', 'MS_Offline TA/TO', 'MS_Online TA',
#        'DC_Direct', 'DC_TA/TO', 'DC_Undefined', 'MEAL_FB', 'MEAL_HB',
# ...

# %%
h1_res.columns
# Out:
# Index(['ResNum', 'IsCanceled', 'LeadTime', 'ArrivalDateYear',
#        'ArrivalDateMonth', 'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatus', 'ReservationStatusDate',
#        'ArrivalDate', 'LOS', 'PreviousBookings', 'ResMadeDate', 'NumPeople',
#        'CT_is_grp', 'CT_is_trn', 'CT_is_trnP', 'RS_No-Show', 'MS_Corporate',
#        'MS_Direct', 'MS_Groups', 'MS_Offline TA/TO', 'MS_Online TA',
#        'DC_Direct', 'DC_TA/TO', 'DC_Undefined', 'MEAL_FB', 'MEAL_HB',
# ...

# %%
h1_res.BookingChanges.value_counts()
# Out:
# 0     32252
# 1      5469
# 2      1561
# 3       460
# 4       182
# 5        72
# 6        32
# 7        12
# 8         8
# 9         4
# 10        3
# 13        2
# 12        1
# 16        1
# 17        1
# Name: BookingChanges, dtype: int64

# %%
X1_cols = [
    'LeadTime',
    'LOS',
    'StaysInWeekendNights',
    'StaysInWeekNights',
    'ADR',
    'NumPeople',
    'Adults',
    'Children',
    'Babies',
    'TotalOfSpecialRequests',
    'PreviousBookings',
    'PreviousCancellations',
    'PreviousBookingsNotCanceled',
    'BookingChanges',
    'DaysInWaitingList',
    'RequiredCarParkingSpaces',
    'IsRepeatedGuest',
    'AgencyBooking',
    'CompanyListed',
    'CT_is_grp',
    'CT_is_trn',
    'CT_is_trnP',
    'RS_No-Show',
    'MS_Corporate',
    'MS_Direct',
    'MS_Groups',
    'MS_Offline TA/TO',
    'MS_Online TA',
    'DC_Direct',
    'DC_TA/TO',
    'DC_Undefined',
    'FROM_PRT',
    'FROM_GBR',
    'FROM_ESP',
    'FROM_IRL',
    'FROM_FRA',
    'FROM_DEU',
    'FROM_CN',
    'FROM_NLD',
    'FROM_USA',
    'FROM_ITA',
    'FROM_other',
    'DT_NonRefundable',
    'DT_Refundable',
    'MEAL_Undefined',
    'MEAL_HB',
    'MEAL_FB',
]

# %%
X1_cxl = h1_res[X1_cols].copy()
y1_cxl = h1_res['IsCanceled']

# %%
len(X1_cols)
# Out:
# 47

# %%
X1_cxl.describe()
# Out:
#            LeadTime           LOS  StaysInWeekendNights  StaysInWeekNights  \
# count  40060.000000  40060.000000          40060.000000       40060.000000
# mean      92.675686      4.318547              1.189815           3.128732
# std       97.285315      3.380273              1.147812           2.461329
# min        0.000000      0.000000              0.000000           0.000000
# 25%       10.000000      2.000000              0.000000           1.000000
# 50%       57.000000      3.000000              1.000000           3.000000
# 75%      155.000000      7.000000              2.000000           5.000000
# max      737.000000     69.000000             19.000000          50.000000
#
#                 ADR     NumPeople        Adults      Children        Babies  \
# count  40060.000000  40060.000000  40060.000000  40060.000000  40060.000000
# mean      94.952930      2.009735      1.867149      0.128682      0.013904
# ...

# %%
h2_res.columns
# Out:
# Index(['ResNum', 'IsCanceled', 'LeadTime', 'ArrivalDateYear',
#        'ArrivalDateMonth', 'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatus', 'ReservationStatusDate',
#        'ArrivalDate', 'LOS', 'PreviousBookings', 'ResMadeDate', 'NumPeople',
#        'CT_is_grp', 'CT_is_trn', 'CT_is_trnP', 'RS_No-Show',
#        'MS_Complementary', 'MS_Corporate', 'MS_Direct', 'MS_Groups',
#        'MS_Offline TA/TO', 'MS_Online TA', 'MS_Undefined', 'DC_Direct',
# ...

# %%
X2_cols = [
    'LeadTime',
    'LOS',
    'StaysInWeekendNights',
    'StaysInWeekNights',
    'ADR',
    'NumPeople',
    'Adults',
    'Children',
    'Babies',
    'TotalOfSpecialRequests',
    'PreviousBookings',
    'PreviousCancellations',
    'PreviousBookingsNotCanceled',
    'BookingChanges',
    'DaysInWaitingList',
    'RequiredCarParkingSpaces',
    'IsRepeatedGuest',
    'AgencyBooking',
    'CompanyListed',
    'CT_is_grp',
    'CT_is_trn',
    'CT_is_trnP',
    'RS_No-Show',
    'MS_Complementary',
    'MS_Corporate',
    'MS_Direct',
    'MS_Groups',
    'MS_Offline TA/TO',
    'MS_Online TA',
    'MS_Undefined',
    'DC_Direct',
    'DC_GDS',
    'DC_TA/TO',
    'DC_Undefined',
    'FROM_PRT',
    'FROM_FRA',
    'FROM_DEU',
    'FROM_GBR',
    'FROM_ESP',
    'FROM_ITA',
    'FROM_BEL',
    'FROM_BRA',
    'FROM_USA',
    'FROM_NLD',
    'FROM_other',
    'DT_NonRefundable',
    'DT_Refundable',
    'MEAL_FB',
    'MEAL_HB',
    'MEAL_SC',
]

# %%
X2_cxl = h2_res[X2_cols].copy()
y2_cxl = h2_res['IsCanceled']

# %%
X1_cxl.to_pickle("pickle/X1_cxl.pick")
y1_cxl.to_pickle("pickle/y1_cxl.pick")

X2_cxl.to_pickle("pickle/X2_cxl.pick")
y2_cxl.to_pickle("pickle/y2_cxl.pick")

# %%
X2_cxl.describe()
# Out:
#            LeadTime           LOS  StaysInWeekendNights  StaysInWeekNights  \
# count  79330.000000  79330.000000          79330.000000       79330.000000
# mean     109.735724      2.978142              0.795185           2.182957
# std      110.948526      1.862937              0.885026           1.456416
# min        0.000000      0.000000              0.000000           0.000000
# 25%       23.000000      2.000000              0.000000           1.000000
# 50%       74.000000      3.000000              1.000000           2.000000
# 75%      163.000000      4.000000              2.000000           3.000000
# max      629.000000     57.000000             16.000000          41.000000
#
#                 ADR     NumPeople        Adults      Children        Babies  \
# count  79330.000000  79326.000000  79330.000000  79326.000000  79330.000000
# mean     105.304465      1.947268      1.850977      0.091370      0.004941
# ...

# %%
h2_res[h2_res.NumPeople.isna()]
# Out:
#       ResNum  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 540      540           1         2             2015           August
# 607      607           1         1             2015           August
# 619      619           1         1             2015           August
# 1100    1100           1         8             2015           August
#
#       ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 540                      32                      3                     1
# 607                      32                      5                     0
# 619                      32                      5                     0
# 1100                     33                     13                     2
#
#       StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 540                   0       2       NaN       0  BB            PRT
# 607                   2       2       NaN       0  BB            PRT
# ...
