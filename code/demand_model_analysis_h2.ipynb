# %% [markdown]
# # Modeling Demand for Analysis
#
# **Target variable**: `Proj_TRN_RoomsPickup`: How many transient rooms will be booked for each stay date, from this point (8/1/17) forward, at current prices?

# %%
import pandas as pd
import numpy as np
import re
import datetime as dt
from agg import prep_demand_features
from demand_features import rf_cols

pd.options.display.max_rows = 162
pd.options.display.max_columns = 250
pd.options.display.max_colwidth = None

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error

DATE_FMT = "%Y-%m-%d"
as_of_date = "2017-08-01"

print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
date_cols = ['StayDate',
 'STLY_StayDate',
 'AsOfDate',
 'STLY_AsOfDate',
 'AsOfDate_STLY',
 'StayDate_STLY']

h1_stats = pd.read_csv("../data/h1_stats.csv", parse_dates=date_cols, infer_datetime_format=True)
h1_stats.drop(columns=["STLY_Stay_Date", "STLY_AsOfDate", "Unnamed: 0"], errors='ignore', inplace=True) # remove dup. columns

# %%
h1_stats.head()
# Out:
#                         id  DOW  RoomsOTB    RevOTB  CxlForecast  \
# 0  2016-07-31 - 2016-07-31  Sun     170.0  28570.36         25.0
# 1  2016-07-31 - 2016-08-01  Mon     178.0  29525.52         31.0
# 2  2016-07-31 - 2016-08-02  Tue     182.0  30820.89         35.0
# 3  2016-07-31 - 2016-08-03  Wed     174.0  30144.62         38.0
# 4  2016-07-31 - 2016-08-04  Thu     179.0  32412.13         42.0
#
#    TRN_RoomsOTB  TRN_RevOTB  TRN_CxlForecast  TRNP_RoomsOTB  GRP_RoomsOTB  \
# 0         137.0    23869.77             23.0           22.0           0.0
# 1         148.0    25429.03             30.0           20.0           0.0
# 2         158.0    27539.05             34.0           14.0           0.0
# 3         152.0    27062.88             36.0           14.0           0.0
# 4         149.0    27503.67             38.0           20.0           0.0
#
#    CNT_RoomsOTB   StayDate STLY_StayDate  DaysUntilArrival  Realized_Cxls  \
# 0          11.0 2016-07-31    2015-08-02               0.0           66.0
# 1          10.0 2016-08-01    2015-08-03               1.0           70.0
# 2          10.0 2016-08-02    2015-08-04               2.0           80.0
# 3           8.0 2016-08-03    2015-08-05               3.0           85.0
# 4          10.0 2016-08-04    2015-08-06               4.0           94.0
#
#    SellingPrice  TM30_RoomsOTB  TM30_RevOTB  TM30_TRN_RoomsOTB  \
# 0        179.12          150.0     23981.92              122.0
# 1        176.01          175.0     28404.00              145.0
# 2        178.09          180.0     29880.26              156.0
# 3        181.69          179.0     30517.59              157.0
# 4        187.83          173.0     30621.96              145.0
#
#    TM30_TRN_RevOTB  TM15_RoomsOTB  TM15_RevOTB  TM15_TRN_RoomsOTB  \
# 0         20315.33          155.0     25254.01              127.0
# 1         24307.51          175.0     28536.80              145.0
# 2         26598.42          180.0     30125.10              156.0
# 3         27435.85          176.0     30361.96              154.0
# 4         26214.16          177.0     31801.65              149.0
#
#    TM15_TRN_RevOTB  TM05_RoomsOTB  TM05_RevOTB  TM05_TRN_RoomsOTB  \
# 0         21587.42          162.0     26749.13              128.0
# 1         24440.31          171.0     27933.34              141.0
# 2         26843.26          182.0     30598.64              158.0
# 3         27280.22          173.0     29906.87              151.0
# 4         27393.85          177.0     31930.67              149.0
#
#    TM05_TRN_RevOTB   AsOfDate  RemSupply  ADR_OTB  TRN_ADR_OTB  LYA_RoomsSold  \
# 0         21866.54 2016-07-31       42.0   168.06       174.23          168.0
# 1         23836.85 2016-07-31       40.0   165.87       171.82          178.0
# 2         27316.80 2016-07-31       40.0   169.35       174.30          182.0
# 3         26825.13 2016-07-31       51.0   173.24       178.05          182.0
# 4         27522.87 2016-07-31       50.0   181.07       184.59          180.0
#
#    LYA_ADR  LYA_RoomRev  LYA_NumCancels  LYA_TRN_RoomsSold  LYA_TRN_ADR  \
# 0   144.92     24346.11            68.0              129.0       153.96
# 1   149.32     26579.60            54.0              133.0       161.24
# 2   151.57     27585.83            58.0              132.0       164.59
# 3   152.92     27831.73            59.0              137.0       164.13
# 4   155.27     27947.92            57.0              137.0       166.14
#
#    LYA_TRN_RoomRev  ACTUAL_RoomsSold  ACTUAL_ADR  ACTUAL_RoomRev  \
# 0         19860.51             170.0      168.06        28570.36
# 1         21444.49             180.0      165.72        29830.01
# 2         21725.78             183.0      170.00        31110.89
# 3         22485.30             182.0      173.96        31660.62
# 4         22760.64             183.0      182.11        33326.17
#
#    ACTUAL_TRN_RoomsSold  ACTUAL_TRN_ADR  ACTUAL_TRN_RoomRev  \
# 0                 137.0          174.23            23869.77
# 1                 150.0          171.56            25733.52
# 2                 159.0          175.03            27829.05
# 3                 159.0          178.23            28337.88
# 4                 153.0          185.74            28417.71
#
#    ACTUAL_NumCancels  ACTUAL_RoomsPickup  ACTUAL_ADR_Pickup  ACTUAL_RevPickup  \
# 0               66.0                 0.0               0.00              0.00
# 1               71.0                 2.0              -0.15            304.49
# 2               81.0                 1.0               0.65            290.00
# 3               86.0                 8.0               0.72           1516.00
# 4               96.0                 4.0               1.04            914.04
#
#    ACTUAL_TRN_RoomsPickup  ACTUAL_TRN_ADR_Pickup  ACTUAL_TRN_RevPickup  \
# 0                     0.0                   0.00                  0.00
# 1                     2.0                  -0.26                304.49
# 2                     1.0                   0.73                290.00
# 3                     7.0                   0.18               1275.00
# 4                     4.0                   1.15                914.04
#
#    MonthNum DayOfWeek    Mon    Sat  Sun    Thu    Tue    Wed     WE  \
# 0         7       Sun  False  False    1  False  False  False  False
# 1         8       Mon   True  False    0  False  False  False  False
# 2         8       Tue  False  False    0  False   True  False  False
# 3         8       Wed  False  False    0  False  False   True  False
# 4         8       Thu  False  False    0   True  False  False  False
#
#    week_of_year  TM30_ADR_OTB  TM30_RoomsPickup  TM30_RevPickup  \
# 0          30.0        159.88              20.0         4588.44
# 1          31.0        162.31               3.0         1121.52
# 2          31.0        166.00               2.0          940.63
# 3          31.0        170.49              -5.0         -372.97
# 4          31.0        177.01               6.0         1790.17
#
#    TM30_ADR_Pickup  TM30_TRN_ADR_OTB  TM30_TRN_RoomsPickup  \
# 0             8.18            166.52                  15.0
# 1             3.56            167.64                   3.0
# 2             3.35            170.50                   2.0
# 3             2.75            174.75                  -5.0
# 4             4.06            180.79                   4.0
#
#    TM30_TRN_RevPickup  TM30_TRN_ADR_Pickup  TM15_ADR_OTB  TM15_RoomsPickup  \
# 0             3554.44                 7.71        162.93              15.0
# 1             1121.52                 4.18        163.07               3.0
# 2              940.63                 3.80        167.36               2.0
# 3             -372.97                 3.30        172.51              -2.0
# 4             1289.51                 3.80        179.67               2.0
#
#    TM15_RevPickup  TM15_ADR_Pickup  TM15_TRN_ADR_OTB  TM15_TRN_RoomsPickup  \
# 0         3316.35             5.13            169.98                  10.0
# 1          988.72             2.80            168.55                   3.0
# 2          695.79             1.99            172.07                   2.0
# 3         -217.34             0.73            177.14                  -2.0
# 4          610.48             1.40            183.85                   0.0
#
#    TM15_TRN_RevPickup  TM15_TRN_ADR_Pickup  TM05_ADR_OTB  TM05_RoomsPickup  \
# 0             2282.35                 4.25        165.12               8.0
# 1              988.72                 3.27        163.35               7.0
# 2              695.79                 2.23        168.12               0.0
# 3             -217.34                 0.91        172.87               1.0
# 4              109.82                 0.74        180.40               2.0
#
#    TM05_RevPickup  TM05_ADR_Pickup  TM05_TRN_ADR_OTB  TM05_TRN_RoomsPickup  \
# 0         1821.23             2.94            170.83                   9.0
# 1         1592.18             2.52            169.06                   7.0
# 2          222.25             1.23            172.89                   0.0
# 3          237.75             0.37            177.65                   1.0
# 4          481.46             0.67            184.72                   0.0
#
#    TM05_TRN_RevPickup  TM05_TRN_ADR_Pickup  OTB_GapToLYA_RoomsSold  \
# 0             2003.23                 3.40                    -2.0
# 1             1592.18                 2.76                     0.0
# 2              222.25                 1.41                     0.0
# 3              237.75                 0.40                     8.0
# 4              -19.20                -0.13                     1.0
#
#    OTB_GapToLYA_ADR  OTB_GapToLYA_RoomRev  OTB_GapToLYA_NumCancels  \
# 0            -23.14              -4224.25                      2.0
# 1            -16.55              -2945.92                    -16.0
# 2            -17.78              -3235.06                    -22.0
# 3            -20.32              -2312.89                    -26.0
# 4            -25.80              -4464.21                    -37.0
#
#    OTB_GapToLYA_TRN_RoomsSold  OTB_GapToLYA_TRN_ADR  OTB_GapToLYA_TRN_RoomRev  \
# 0                        -8.0                -20.27                  -4009.26
# 1                       -15.0                -10.58                  -3984.54
# 2                       -26.0                 -9.71                  -5813.27
# 3                       -15.0                -13.92                  -4577.58
# 4                       -12.0                -18.45                  -4743.03
#
#                    id_STLY AsOfDate_STLY StayDate_STLY  RoomsOTB_STLY  \
# 0  2015-08-02 - 2015-08-02    2015-08-02    2015-08-02          168.0
# 1  2015-08-02 - 2015-08-03    2015-08-02    2015-08-03          175.0
# 2  2015-08-02 - 2015-08-04    2015-08-02    2015-08-04          178.0
# 3  2015-08-02 - 2015-08-05    2015-08-02    2015-08-05          175.0
# 4  2015-08-02 - 2015-08-06    2015-08-02    2015-08-06          176.0
#
#    ADR_OTB_STLY  RevOTB_STLY  ACTUAL_RoomsPickup_STLY  ACTUAL_ADR_Pickup_STLY  \
# 0        144.92     24346.11                      0.0                    0.00
# 1        148.92     26061.40                      3.0                    0.40
# 2        150.17     26730.73                      4.0                    1.40
# 3        151.26     26469.93                      7.0                    1.66
# 4        153.78     27065.32                      4.0                    1.49
#
#    ACTUAL_RevPickup_STLY  CxlForecast_STLY  RemSupply_STLY  SellingPrice_STLY  \
# 0                    0.0              22.0            41.0             153.37
# 1                  518.2              26.0            38.0             160.36
# 2                  855.1              26.0            35.0             163.14
# 3                 1361.8              28.0            40.0             163.93
# 4                  882.6              30.0            41.0             164.97
#
#    Realized_Cxls_STLY  TRN_RoomsOTB_STLY  TRN_ADR_OTB_STLY  TRN_RevOTB_STLY  \
# 0                68.0              129.0            153.96         19860.51
# 1                54.0              130.0            160.97         20926.29
# 2                57.0              128.0            163.05         20870.68
# 3                57.0              130.0            162.49         21123.50
# 4                56.0              133.0            164.50         21878.04
#
#    TRN_CxlForecast_STLY  ACTUAL_TRN_RoomsPickup_STLY  \
# 0                  21.0                          0.0
# 1                  25.0                          3.0
# 2                  25.0                          4.0
# 3                  27.0                          7.0
# 4                  27.0                          4.0
#
#    ACTUAL_TRN_ADR_Pickup_STLY  ACTUAL_TRN_RevPickup_STLY  \
# 0                        0.00                        0.0
# 1                        0.27                      518.2
# 2                        1.54                      855.1
# 3                        1.64                     1361.8
# 4                        1.64                      882.6
#
#    TM30_RoomsPickup_STLY  TM30_ADR_Pickup_STLY  TM30_RevPickup_STLY  \
# 0                    7.0                  4.16              1683.25
# 1                    3.0                  3.58              1062.52
# 2                    1.0                  3.83               829.12
# 3                    1.0                  2.96               666.12
# 4                    7.0                  4.81              1889.43
#
#    TM30_TRN_RoomsPickup_STLY  TM30_TRN_ADR_Pickup_STLY  \
# 0                       10.0                      4.81
# 1                        6.0                      4.36
# 2                        2.0                      3.85
# 3                        2.0                      2.53
# 4                        8.0                      4.45
#
#    TM30_TRN_RevPickup_STLY  TM15_RoomsPickup_STLY  TM15_ADR_Pickup_STLY  \
# 0                  2111.23                    7.0                  2.54
# 1                  1506.50                    7.0                  2.65
# 2                   812.10                    6.0                  3.10
# 3                   649.10                    1.0                  0.41
# 4                  1872.41                    2.0                  0.36
#
#    TM15_RevPickup_STLY  TM15_TRN_RoomsPickup_STLY  TM15_TRN_ADR_Pickup_STLY  \
# 0              1422.56                        9.0                      2.99
# 1              1488.83                        9.0                      2.98
# 2              1434.03                        6.0                      2.59
# 3               222.25                        2.0                     -0.17
# 4               370.04                        4.0                      1.02
#
#    TM15_TRN_RevPickup_STLY  TM05_RoomsPickup_STLY  TM05_ADR_Pickup_STLY  \
# 0                  1743.54                    6.0                  1.37
# 1                  1809.81                    2.0                  0.29
# 2                  1294.01                    2.0                  0.17
# 3                   302.78                    1.0                 -0.17
# 4                   789.59                    0.0                  0.00
#
#    TM05_RevPickup_STLY  TM05_TRN_RoomsPickup_STLY  TM05_TRN_ADR_Pickup_STLY  \
# 0              1090.87                        6.0                      1.36
# 1               349.09                        2.0                      0.21
# 2               331.60                        2.0                      0.04
# 3               120.60                        1.0                     -0.32
# 4                 0.00                        0.0                      0.00
#
#    TM05_TRN_RevPickup_STLY  Pace_RoomsOTB  Pace_ADR_OTB  Pace_RevOTB  \
# 0                  1090.87            2.0         23.14      4224.25
# 1                   349.09            3.0         16.95      3464.12
# 2                   331.60            4.0         19.18      4090.16
# 3                   120.60           -1.0         21.98      3674.69
# 4                    -0.00            3.0         27.29      5346.81
#
#    Pace_CxlForecast  Pace_RemSupply  Pace_SellingPrice  Pace_TRN_RoomsOTB  \
# 0               3.0             1.0              25.75                8.0
# 1               5.0             2.0              15.65               18.0
# 2               9.0             5.0              14.95               30.0
# 3              10.0            11.0              17.76               22.0
# 4              12.0             9.0              22.86               16.0
#
#    Pace_TRN_ADR_OTB  Pace_TRN_RevOTB  Pace_TRN_CxlForecast  \
# 0             20.27          4009.26                   2.0
# 1             10.85          4502.74                   5.0
# 2             11.25          6668.37                   9.0
# 3             15.56          5939.38                   9.0
# 4             20.09          5625.63                  11.0
#
#    Pace_TM30_RoomsPickup  Pace_TM30_ADR_Pickup  Pace_TM30_RevPickup  \
# 0                   13.0                  4.02              2905.19
# 1                    0.0                 -0.02                59.00
# 2                    1.0                 -0.48               111.51
# 3                   -6.0                 -0.21             -1039.09
# 4                   -1.0                 -0.75               -99.26
#
#    Pace_TM30_TRN_RoomsPickup  Pace_TM30_TRN_ADR_Pickup  \
# 0                        5.0                      2.90
# 1                       -3.0                     -0.18
# 2                        0.0                     -0.05
# 3                       -7.0                      0.77
# 4                       -4.0                     -0.65
#
#    Pace_TM30_TRN_RevPickup  Pace_TM15_RoomsPickup  Pace_TM15_ADR_Pickup  \
# 0                  1443.21                    8.0                  2.59
# 1                  -384.98                   -4.0                  0.15
# 2                   128.53                   -4.0                 -1.11
# 3                 -1022.07                   -3.0                  0.32
# 4                  -582.90                    0.0                  1.04
#
#    Pace_TM15_RevPickup  Pace_TM15_TRN_RoomsPickup  Pace_TM15_TRN_ADR_Pickup  \
# 0              1893.79                        1.0                      1.26
# 1              -500.11                       -6.0                      0.29
# 2              -738.24                       -4.0                     -0.36
# 3              -439.59                       -4.0                      1.08
# 4               240.44                       -4.0                     -0.28
#
#    Pace_TM15_TRN_RevPickup  Pace_TM05_RoomsPickup  Pace_TM05_ADR_Pickup  \
# 0                   538.81                    2.0                  1.57
# 1                  -821.09                    5.0                  2.23
# 2                  -598.22                   -2.0                  1.06
# 3                  -520.12                    0.0                  0.54
# 4                  -679.77                    2.0                  0.67
#
#    Pace_TM05_RevPickup  Pace_TM05_TRN_RoomsPickup  Pace_TM05_TRN_ADR_Pickup  \
# 0               730.36                        3.0                      2.04
# 1              1243.09                        5.0                      2.55
# 2              -109.35                       -2.0                      1.37
# 3               117.15                        0.0                      0.72
# 4               481.46                        0.0                     -0.13
#
#    Pace_TM05_TRN_RevPickup
# 0                   912.36
# 1                  1243.09
# 2                  -109.35
# 3                   117.15
# 4                   -19.20

# %%
len(rf_cols)
# Out:
# 40

# %% [markdown]
# ## Splitting Up Our Data for Train/Test
#
# For a Revenue Management application:
# * Our training set will contain all dates prior to as_of_date.
# * Our testing set will contain 31 stay dates starting on as_of_date. Our predictions will be used to provide price recommendations later on.

# %%
# method for application

mask = (h1_stats["StayDate"] < as_of_date)
test_mask = (h1_stats['AsOfDate'] >= as_of_date)
df_train = h1_stats.loc[mask].copy()
df_test = h1_stats.loc[test_mask].copy()

X_train = df_train[rf_cols].copy()
X_test = df_test[rf_cols].copy()
y_train = df_train['ACTUAL_TRN_RoomsPickup'].copy()
y_test = df_test['ACTUAL_TRN_RoomsPickup'].copy()

# %% [markdown]
# ## Final Model
#
# Using the params generate in demand_model_selection

# %%
rf = RandomForestRegressor(n_estimators=550, n_jobs=-1, random_state=20)

rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.7582961090550975

# %%
# add predictions to h1_stats for futher analysis

mask = h1_stats["AsOfDate"] >= as_of_date
h1_stat_preds = h1_stats[mask].copy()


preds = rf.predict(X_test)
h1_stat_preds["DemandPrediction"] = preds.round(0)
h1_stat_preds.index = h1_stat_preds.id

# %%
h1_stat_preds.head()
# Out:
#                                               id  DOW  RoomsOTB    RevOTB  \
# id
# 2017-07-01 - 2017-07-01  2017-07-01 - 2017-07-01  Sat     176.0  22555.69
# 2017-07-01 - 2017-07-02  2017-07-01 - 2017-07-02  Sun     167.0  21363.33
# 2017-07-01 - 2017-07-03  2017-07-01 - 2017-07-03  Mon     166.0  21384.89
# 2017-07-01 - 2017-07-04  2017-07-01 - 2017-07-04  Tue     178.0  23412.02
# 2017-07-01 - 2017-07-05  2017-07-01 - 2017-07-05  Wed     176.0  23613.57
#
#                          CxlForecast  TRN_RoomsOTB  TRN_RevOTB  \
# id
# 2017-07-01 - 2017-07-01         40.0         130.0    17860.92
# 2017-07-01 - 2017-07-02         39.0         120.0    16546.69
# 2017-07-01 - 2017-07-03         42.0         118.0    16173.43
# 2017-07-01 - 2017-07-04         48.0         131.0    18183.71
# 2017-07-01 - 2017-07-05         53.0         134.0    18885.69
#
#                          TRN_CxlForecast  TRNP_RoomsOTB  GRP_RoomsOTB  \
# id
# 2017-07-01 - 2017-07-01             40.0           13.0           2.0
# 2017-07-01 - 2017-07-02             39.0           11.0           2.0
# 2017-07-01 - 2017-07-03             42.0           14.0           2.0
# 2017-07-01 - 2017-07-04             48.0           14.0           2.0
# 2017-07-01 - 2017-07-05             52.0           10.0           2.0
#
#                          CNT_RoomsOTB   StayDate STLY_StayDate  \
# id
# 2017-07-01 - 2017-07-01          31.0 2017-07-01    2016-07-02
# 2017-07-01 - 2017-07-02          34.0 2017-07-02    2016-07-03
# 2017-07-01 - 2017-07-03          32.0 2017-07-03    2016-07-04
# 2017-07-01 - 2017-07-04          31.0 2017-07-04    2016-07-05
# 2017-07-01 - 2017-07-05          30.0 2017-07-05    2016-07-06
#
#                          DaysUntilArrival  Realized_Cxls  SellingPrice  \
# id
# 2017-07-01 - 2017-07-01               0.0          133.0        133.85
# 2017-07-01 - 2017-07-02               1.0          123.0        136.91
# 2017-07-01 - 2017-07-03               2.0          133.0        142.52
# 2017-07-01 - 2017-07-04               3.0          132.0        144.17
# 2017-07-01 - 2017-07-05               4.0          127.0        146.19
#
#                          TM30_RoomsOTB  TM30_RevOTB  TM30_TRN_RoomsOTB  \
# id
# 2017-07-01 - 2017-07-01          163.0     20019.26              115.0
# 2017-07-01 - 2017-07-02          166.0     20804.72              118.0
# 2017-07-01 - 2017-07-03          168.0     21565.95              119.0
# 2017-07-01 - 2017-07-04          182.0     23961.83              134.0
# 2017-07-01 - 2017-07-05          175.0     23349.51              131.0
#
#                          TM30_TRN_RevOTB  TM15_RoomsOTB  TM15_RevOTB  \
# id
# 2017-07-01 - 2017-07-01         15143.29          167.0     20894.40
# 2017-07-01 - 2017-07-02         15938.13          166.0     21086.53
# 2017-07-01 - 2017-07-03         16304.54          169.0     21984.33
# 2017-07-01 - 2017-07-04         18683.57          179.0     23582.21
# 2017-07-01 - 2017-07-05         18448.30          173.0     23131.14
#
#                          TM15_TRN_RoomsOTB  TM15_TRN_RevOTB  TM05_RoomsOTB  \
# id
# 2017-07-01 - 2017-07-01              120.0         16068.38          173.0
# 2017-07-01 - 2017-07-02              119.0         16269.89          166.0
# 2017-07-01 - 2017-07-03              121.0         16772.87          166.0
# 2017-07-01 - 2017-07-04              132.0         18353.90          179.0
# 2017-07-01 - 2017-07-05              130.0         18279.88          176.0
#
#                          TM05_RevOTB  TM05_TRN_RoomsOTB  TM05_TRN_RevOTB  \
# id
# 2017-07-01 - 2017-07-01     22078.08              126.0         17252.06
# 2017-07-01 - 2017-07-02     21079.97              119.0         16263.33
# 2017-07-01 - 2017-07-03     21384.89              118.0         16173.43
# 2017-07-01 - 2017-07-04     23412.02              132.0         18183.71
# 2017-07-01 - 2017-07-05     23613.57              134.0         18885.69
#
#                           AsOfDate  RemSupply  ADR_OTB  TRN_ADR_OTB  \
# id
# 2017-07-01 - 2017-07-01 2017-07-01       51.0   128.16       137.39
# 2017-07-01 - 2017-07-02 2017-07-01       59.0   127.92       137.89
# 2017-07-01 - 2017-07-03 2017-07-01       63.0   128.82       137.06
# 2017-07-01 - 2017-07-04 2017-07-01       57.0   131.53       138.81
# 2017-07-01 - 2017-07-05 2017-07-01       64.0   134.17       140.94
#
#                          LYA_RoomsSold  LYA_ADR  LYA_RoomRev  LYA_NumCancels  \
# id
# 2017-07-01 - 2017-07-01          183.0    98.51     18026.47            67.0
# 2017-07-01 - 2017-07-02          164.0    97.33     15962.41            68.0
# 2017-07-01 - 2017-07-03          180.0   100.84     18150.67            73.0
# 2017-07-01 - 2017-07-04          182.0   103.74     18881.54            65.0
# 2017-07-01 - 2017-07-05          181.0   107.23     19409.42            63.0
#
#                          LYA_TRN_RoomsSold  LYA_TRN_ADR  LYA_TRN_RoomRev  \
# id
# 2017-07-01 - 2017-07-01              124.0       107.80         13367.56
# 2017-07-01 - 2017-07-02              112.0       105.66         11833.46
# 2017-07-01 - 2017-07-03              121.0       108.26         13099.54
# 2017-07-01 - 2017-07-04              123.0       112.38         13823.35
# 2017-07-01 - 2017-07-05              117.0       117.38         13733.23
#
#                          ACTUAL_RoomsSold  ACTUAL_ADR  ACTUAL_RoomRev  \
# id
# 2017-07-01 - 2017-07-01             176.0      128.16        22555.69
# 2017-07-01 - 2017-07-02             170.0      128.02        21764.07
# 2017-07-01 - 2017-07-03             172.0      129.55        22282.09
# 2017-07-01 - 2017-07-04             182.0      131.91        24008.22
# 2017-07-01 - 2017-07-05             184.0      133.52        24567.77
#
#                          ACTUAL_TRN_RoomsSold  ACTUAL_TRN_ADR  \
# id
# 2017-07-01 - 2017-07-01                 130.0          137.39
# 2017-07-01 - 2017-07-02                 123.0          137.78
# 2017-07-01 - 2017-07-03                 124.0          137.67
# 2017-07-01 - 2017-07-04                 135.0          139.11
# 2017-07-01 - 2017-07-05                 140.0          140.21
#
#                          ACTUAL_TRN_RoomRev  ACTUAL_NumCancels  \
# id
# 2017-07-01 - 2017-07-01            17860.92              133.0
# 2017-07-01 - 2017-07-02            16947.43              123.0
# 2017-07-01 - 2017-07-03            17070.63              133.0
# 2017-07-01 - 2017-07-04            18779.91              132.0
# 2017-07-01 - 2017-07-05            19628.89              129.0
#
#                          ACTUAL_RoomsPickup  ACTUAL_ADR_Pickup  \
# id
# 2017-07-01 - 2017-07-01                 0.0               0.00
# 2017-07-01 - 2017-07-02                 3.0               0.10
# 2017-07-01 - 2017-07-03                 6.0               0.73
# 2017-07-01 - 2017-07-04                 4.0               0.38
# 2017-07-01 - 2017-07-05                 8.0              -0.65
#
#                          ACTUAL_RevPickup  ACTUAL_TRN_RoomsPickup  \
# id
# 2017-07-01 - 2017-07-01              0.00                     0.0
# 2017-07-01 - 2017-07-02            400.74                     3.0
# 2017-07-01 - 2017-07-03            897.20                     6.0
# 2017-07-01 - 2017-07-04            596.20                     4.0
# 2017-07-01 - 2017-07-05            954.20                     6.0
#
#                          ACTUAL_TRN_ADR_Pickup  ACTUAL_TRN_RevPickup  \
# id
# 2017-07-01 - 2017-07-01                   0.00                  0.00
# 2017-07-01 - 2017-07-02                  -0.11                400.74
# 2017-07-01 - 2017-07-03                   0.61                897.20
# 2017-07-01 - 2017-07-04                   0.30                596.20
# 2017-07-01 - 2017-07-05                  -0.73                743.20
#
#                          MonthNum DayOfWeek    Mon    Sat  Sun    Thu    Tue  \
# id
# 2017-07-01 - 2017-07-01         7       Sat  False   True    0  False  False
# 2017-07-01 - 2017-07-02         7       Sun  False  False    1  False  False
# 2017-07-01 - 2017-07-03         7       Mon   True  False    0  False  False
# 2017-07-01 - 2017-07-04         7       Tue  False  False    0  False   True
# 2017-07-01 - 2017-07-05         7       Wed  False  False    0  False  False
#
#                            Wed     WE  week_of_year  TM30_ADR_OTB  \
# id
# 2017-07-01 - 2017-07-01  False   True          26.0        122.82
# 2017-07-01 - 2017-07-02  False  False          26.0        125.33
# 2017-07-01 - 2017-07-03  False  False          27.0        128.37
# 2017-07-01 - 2017-07-04  False  False          27.0        131.66
# 2017-07-01 - 2017-07-05   True  False          27.0        133.43
#
#                          TM30_RoomsPickup  TM30_RevPickup  TM30_ADR_Pickup  \
# id
# 2017-07-01 - 2017-07-01              13.0         2536.43             5.34
# 2017-07-01 - 2017-07-02               1.0          558.61             2.59
# 2017-07-01 - 2017-07-03              -2.0         -181.06             0.45
# 2017-07-01 - 2017-07-04              -4.0         -549.81            -0.13
# 2017-07-01 - 2017-07-05               1.0          264.06             0.74
#
#                          TM30_TRN_ADR_OTB  TM30_TRN_RoomsPickup  \
# id
# 2017-07-01 - 2017-07-01            131.68                  15.0
# 2017-07-01 - 2017-07-02            135.07                   2.0
# 2017-07-01 - 2017-07-03            137.01                  -1.0
# 2017-07-01 - 2017-07-04            139.43                  -3.0
# 2017-07-01 - 2017-07-05            140.83                   3.0
#
#                          TM30_TRN_RevPickup  TM30_TRN_ADR_Pickup  \
# id
# 2017-07-01 - 2017-07-01             2717.63                 5.71
# 2017-07-01 - 2017-07-02              608.56                 2.82
# 2017-07-01 - 2017-07-03             -131.11                 0.05
# 2017-07-01 - 2017-07-04             -499.86                -0.62
# 2017-07-01 - 2017-07-05              437.39                 0.11
#
#                          TM15_ADR_OTB  TM15_RoomsPickup  TM15_RevPickup  \
# id
# 2017-07-01 - 2017-07-01        125.12               9.0         1661.29
# 2017-07-01 - 2017-07-02        127.03               1.0          276.80
# 2017-07-01 - 2017-07-03        130.08              -3.0         -599.44
# 2017-07-01 - 2017-07-04        131.74              -1.0         -170.19
# 2017-07-01 - 2017-07-05        133.71               3.0          482.43
#
#                          TM15_ADR_Pickup  TM15_TRN_ADR_OTB  \
# id
# 2017-07-01 - 2017-07-01             3.04            133.90
# 2017-07-01 - 2017-07-02             0.89            136.72
# 2017-07-01 - 2017-07-03            -1.26            138.62
# 2017-07-01 - 2017-07-04            -0.21            139.04
# 2017-07-01 - 2017-07-05             0.46            140.61
#
#                          TM15_TRN_RoomsPickup  TM15_TRN_RevPickup  \
# id
# 2017-07-01 - 2017-07-01                  10.0             1792.54
# 2017-07-01 - 2017-07-02                   1.0              276.80
# 2017-07-01 - 2017-07-03                  -3.0             -599.44
# 2017-07-01 - 2017-07-04                  -1.0             -170.19
# 2017-07-01 - 2017-07-05                   4.0              605.81
#
#                          TM15_TRN_ADR_Pickup  TM05_ADR_OTB  TM05_RoomsPickup  \
# id
# 2017-07-01 - 2017-07-01                 3.49        127.62               3.0
# 2017-07-01 - 2017-07-02                 1.17        126.99               1.0
# 2017-07-01 - 2017-07-03                -1.56        128.82               0.0
# 2017-07-01 - 2017-07-04                -0.23        130.79              -1.0
# 2017-07-01 - 2017-07-05                 0.33        134.17               0.0
#
#                          TM05_RevPickup  TM05_ADR_Pickup  TM05_TRN_ADR_OTB  \
# id
# 2017-07-01 - 2017-07-01          477.61             0.54            136.92
# 2017-07-01 - 2017-07-02          283.36             0.93            136.67
# 2017-07-01 - 2017-07-03            0.00             0.00            137.06
# 2017-07-01 - 2017-07-04           -0.00             0.74            137.76
# 2017-07-01 - 2017-07-05            0.00             0.00            140.94
#
#                          TM05_TRN_RoomsPickup  TM05_TRN_RevPickup  \
# id
# 2017-07-01 - 2017-07-01                   4.0              608.86
# 2017-07-01 - 2017-07-02                   1.0              283.36
# 2017-07-01 - 2017-07-03                   0.0                0.00
# 2017-07-01 - 2017-07-04                  -1.0                0.00
# 2017-07-01 - 2017-07-05                   0.0                0.00
#
#                          TM05_TRN_ADR_Pickup  OTB_GapToLYA_RoomsSold  \
# id
# 2017-07-01 - 2017-07-01                 0.47                     7.0
# 2017-07-01 - 2017-07-02                 1.22                    -3.0
# 2017-07-01 - 2017-07-03                 0.00                    14.0
# 2017-07-01 - 2017-07-04                 1.05                     4.0
# 2017-07-01 - 2017-07-05                 0.00                     5.0
#
#                          OTB_GapToLYA_ADR  OTB_GapToLYA_RoomRev  \
# id
# 2017-07-01 - 2017-07-01            -29.65              -4529.22
# 2017-07-01 - 2017-07-02            -30.59              -5400.92
# 2017-07-01 - 2017-07-03            -27.98              -3234.22
# 2017-07-01 - 2017-07-04            -27.79              -4530.48
# 2017-07-01 - 2017-07-05            -26.94              -4204.15
#
#                          OTB_GapToLYA_NumCancels  OTB_GapToLYA_TRN_RoomsSold  \
# id
# 2017-07-01 - 2017-07-01                    -66.0                        -6.0
# 2017-07-01 - 2017-07-02                    -55.0                        -8.0
# 2017-07-01 - 2017-07-03                    -60.0                         3.0
# 2017-07-01 - 2017-07-04                    -67.0                        -8.0
# 2017-07-01 - 2017-07-05                    -64.0                       -17.0
#
#                          OTB_GapToLYA_TRN_ADR  OTB_GapToLYA_TRN_RoomRev  \
# id
# 2017-07-01 - 2017-07-01                -29.59                  -4493.36
# 2017-07-01 - 2017-07-02                -32.23                  -4713.23
# 2017-07-01 - 2017-07-03                -28.80                  -3073.89
# 2017-07-01 - 2017-07-04                -26.43                  -4360.36
# 2017-07-01 - 2017-07-05                -23.56                  -5152.46
#
#                                          id_STLY AsOfDate_STLY StayDate_STLY  \
# id
# 2017-07-01 - 2017-07-01  2016-07-02 - 2016-07-02    2016-07-02    2016-07-02
# 2017-07-01 - 2017-07-02  2016-07-02 - 2016-07-03    2016-07-02    2016-07-03
# 2017-07-01 - 2017-07-03  2016-07-02 - 2016-07-04    2016-07-02    2016-07-04
# 2017-07-01 - 2017-07-04  2016-07-02 - 2016-07-05    2016-07-02    2016-07-05
# 2017-07-01 - 2017-07-05  2016-07-02 - 2016-07-06    2016-07-02    2016-07-06
#
#                          RoomsOTB_STLY  ADR_OTB_STLY  RevOTB_STLY  \
# id
# 2017-07-01 - 2017-07-01          183.0         98.51     18026.47
# 2017-07-01 - 2017-07-02          161.0         97.25     15657.77
# 2017-07-01 - 2017-07-03          177.0         99.52     17614.67
# 2017-07-01 - 2017-07-04          178.0        102.61     18265.11
# 2017-07-01 - 2017-07-05          181.0        106.29     19238.42
#
#                          ACTUAL_RoomsPickup_STLY  ACTUAL_ADR_Pickup_STLY  \
# id
# 2017-07-01 - 2017-07-01                      0.0                    0.00
# 2017-07-01 - 2017-07-02                      3.0                    0.08
# 2017-07-01 - 2017-07-03                      3.0                    1.32
# 2017-07-01 - 2017-07-04                      4.0                    1.13
# 2017-07-01 - 2017-07-05                      0.0                    0.94
#
#                          ACTUAL_RevPickup_STLY  CxlForecast_STLY  \
# id
# 2017-07-01 - 2017-07-01                   0.00              11.0
# 2017-07-01 - 2017-07-02                 304.64              10.0
# 2017-07-01 - 2017-07-03                 536.00              11.0
# 2017-07-01 - 2017-07-04                 616.43              12.0
# 2017-07-01 - 2017-07-05                 171.00              10.0
#
#                          RemSupply_STLY  SellingPrice_STLY  \
# id
# 2017-07-01 - 2017-07-01            15.0             110.42
# 2017-07-01 - 2017-07-02            36.0             106.99
# 2017-07-01 - 2017-07-03            21.0             108.55
# 2017-07-01 - 2017-07-04            21.0             112.28
# 2017-07-01 - 2017-07-05            16.0             116.68
#
#                          Realized_Cxls_STLY  TRN_RoomsOTB_STLY  \
# id
# 2017-07-01 - 2017-07-01                67.0              124.0
# 2017-07-01 - 2017-07-02                68.0              110.0
# 2017-07-01 - 2017-07-03                73.0              118.0
# 2017-07-01 - 2017-07-04                65.0              119.0
# 2017-07-01 - 2017-07-05                62.0              117.0
#
#                          TRN_ADR_OTB_STLY  TRN_RevOTB_STLY  \
# id
# 2017-07-01 - 2017-07-01            107.80         13367.56
# 2017-07-01 - 2017-07-02            105.72         11628.82
# 2017-07-01 - 2017-07-03            106.47         12563.54
# 2017-07-01 - 2017-07-04            110.98         13206.92
# 2017-07-01 - 2017-07-05            115.92         13562.23
#
#                          TRN_CxlForecast_STLY  ACTUAL_TRN_RoomsPickup_STLY  \
# id
# 2017-07-01 - 2017-07-01                  11.0                          0.0
# 2017-07-01 - 2017-07-02                  10.0                          2.0
# 2017-07-01 - 2017-07-03                  11.0                          3.0
# 2017-07-01 - 2017-07-04                  12.0                          4.0
# 2017-07-01 - 2017-07-05                  10.0                          0.0
#
#                          ACTUAL_TRN_ADR_Pickup_STLY  \
# id
# 2017-07-01 - 2017-07-01                        0.00
# 2017-07-01 - 2017-07-02                       -0.06
# 2017-07-01 - 2017-07-03                        1.79
# 2017-07-01 - 2017-07-04                        1.40
# 2017-07-01 - 2017-07-05                        1.46
#
#                          ACTUAL_TRN_RevPickup_STLY  TM30_RoomsPickup_STLY  \
# id
# 2017-07-01 - 2017-07-01                       0.00                    4.0
# 2017-07-01 - 2017-07-02                     204.64                   -4.0
# 2017-07-01 - 2017-07-03                     536.00                   -5.0
# 2017-07-01 - 2017-07-04                     616.43                   -3.0
# 2017-07-01 - 2017-07-05                     171.00                    3.0
#
#                          TM30_ADR_Pickup_STLY  TM30_RevPickup_STLY  \
# id
# 2017-07-01 - 2017-07-01                  6.18              1499.59
# 2017-07-01 - 2017-07-02                  5.97               597.17
# 2017-07-01 - 2017-07-03                  5.77               552.43
# 2017-07-01 - 2017-07-04                  5.47               683.42
# 2017-07-01 - 2017-07-05                  6.88              1543.52
#
#                          TM30_TRN_RoomsPickup_STLY  TM30_TRN_ADR_Pickup_STLY  \
# id
# 2017-07-01 - 2017-07-01                        5.0                      7.37
# 2017-07-01 - 2017-07-02                        0.0                      8.55
# 2017-07-01 - 2017-07-03                       -5.0                      5.85
# 2017-07-01 - 2017-07-04                       -1.0                      5.78
# 2017-07-01 - 2017-07-05                        2.0                      7.00
#
#                          TM30_TRN_RevPickup_STLY  TM15_RoomsPickup_STLY  \
# id
# 2017-07-01 - 2017-07-01                  1416.34                    3.0
# 2017-07-01 - 2017-07-02                   939.92                   -1.0
# 2017-07-01 - 2017-07-03                   187.18                   -1.0
# 2017-07-01 - 2017-07-04                   583.17                    0.0
# 2017-07-01 - 2017-07-05                  1036.77                    6.0
#
#                          TM15_ADR_Pickup_STLY  TM15_RevPickup_STLY  \
# id
# 2017-07-01 - 2017-07-01                  3.88               993.91
# 2017-07-01 - 2017-07-02                  2.99               387.38
# 2017-07-01 - 2017-07-03                  3.21               470.78
# 2017-07-01 - 2017-07-04                  2.68               477.00
# 2017-07-01 - 2017-07-05                  3.24              1204.52
#
#                          TM15_TRN_RoomsPickup_STLY  TM15_TRN_ADR_Pickup_STLY  \
# id
# 2017-07-01 - 2017-07-01                        2.0                      4.54
# 2017-07-01 - 2017-07-02                        1.0                      4.44
# 2017-07-01 - 2017-07-03                       -3.0                      2.34
# 2017-07-01 - 2017-07-04                        0.0                      1.98
# 2017-07-01 - 2017-07-05                        6.0                      2.41
#
#                          TM15_TRN_RevPickup_STLY  TM05_RoomsPickup_STLY  \
# id
# 2017-07-01 - 2017-07-01                   769.31                    1.0
# 2017-07-01 - 2017-07-02                   588.78                    2.0
# 2017-07-01 - 2017-07-03                   -35.82                   -2.0
# 2017-07-01 - 2017-07-04                   235.40                   -2.0
# 2017-07-01 - 2017-07-05                   962.92                   -2.0
#
#                          TM05_ADR_Pickup_STLY  TM05_RevPickup_STLY  \
# id
# 2017-07-01 - 2017-07-01                  0.90               261.77
# 2017-07-01 - 2017-07-02                  0.84               327.87
# 2017-07-01 - 2017-07-03                  0.34              -138.00
# 2017-07-01 - 2017-07-04                  0.37              -138.00
# 2017-07-01 - 2017-07-05                  0.53              -115.60
#
#                          TM05_TRN_RoomsPickup_STLY  TM05_TRN_ADR_Pickup_STLY  \
# id
# 2017-07-01 - 2017-07-01                        2.0                      1.24
# 2017-07-01 - 2017-07-02                        3.0                      1.09
# 2017-07-01 - 2017-07-03                       -1.0                      0.62
# 2017-07-01 - 2017-07-04                       -1.0                      0.65
# 2017-07-01 - 2017-07-05                       -2.0                      0.98
#
#                          TM05_TRN_RevPickup_STLY  Pace_RoomsOTB  Pace_ADR_OTB  \
# id
# 2017-07-01 - 2017-07-01                   367.17           -7.0         29.65
# 2017-07-01 - 2017-07-02                   433.27            6.0         30.67
# 2017-07-01 - 2017-07-03                   -32.60          -11.0         29.30
# 2017-07-01 - 2017-07-04                   -32.60            0.0         28.92
# 2017-07-01 - 2017-07-05                  -115.60           -5.0         27.88
#
#                          Pace_RevOTB  Pace_CxlForecast  Pace_RemSupply  \
# id
# 2017-07-01 - 2017-07-01      4529.22              29.0            36.0
# 2017-07-01 - 2017-07-02      5705.56              29.0            23.0
# 2017-07-01 - 2017-07-03      3770.22              31.0            42.0
# 2017-07-01 - 2017-07-04      5146.91              36.0            36.0
# 2017-07-01 - 2017-07-05      4375.15              43.0            48.0
#
#                          Pace_SellingPrice  Pace_TRN_RoomsOTB  \
# id
# 2017-07-01 - 2017-07-01              23.43                6.0
# 2017-07-01 - 2017-07-02              29.92               10.0
# 2017-07-01 - 2017-07-03              33.97                0.0
# 2017-07-01 - 2017-07-04              31.89               12.0
# 2017-07-01 - 2017-07-05              29.51               17.0
#
#                          Pace_TRN_ADR_OTB  Pace_TRN_RevOTB  \
# id
# 2017-07-01 - 2017-07-01             29.59          4493.36
# 2017-07-01 - 2017-07-02             32.17          4917.87
# 2017-07-01 - 2017-07-03             30.59          3609.89
# 2017-07-01 - 2017-07-04             27.83          4976.79
# 2017-07-01 - 2017-07-05             25.02          5323.46
#
#                          Pace_TRN_CxlForecast  Pace_TM30_RoomsPickup  \
# id
# 2017-07-01 - 2017-07-01                  29.0                    9.0
# 2017-07-01 - 2017-07-02                  29.0                    5.0
# 2017-07-01 - 2017-07-03                  31.0                    3.0
# 2017-07-01 - 2017-07-04                  36.0                   -1.0
# 2017-07-01 - 2017-07-05                  42.0                   -2.0
#
#                          Pace_TM30_ADR_Pickup  Pace_TM30_RevPickup  \
# id
# 2017-07-01 - 2017-07-01                 -0.84              1036.84
# 2017-07-01 - 2017-07-02                 -3.38               -38.56
# 2017-07-01 - 2017-07-03                 -5.32              -733.49
# 2017-07-01 - 2017-07-04                 -5.60             -1233.23
# 2017-07-01 - 2017-07-05                 -6.14             -1279.46
#
#                          Pace_TM30_TRN_RoomsPickup  Pace_TM30_TRN_ADR_Pickup  \
# id
# 2017-07-01 - 2017-07-01                       10.0                     -1.66
# 2017-07-01 - 2017-07-02                        2.0                     -5.73
# 2017-07-01 - 2017-07-03                        4.0                     -5.80
# 2017-07-01 - 2017-07-04                       -2.0                     -6.40
# 2017-07-01 - 2017-07-05                        1.0                     -6.89
#
#                          Pace_TM30_TRN_RevPickup  Pace_TM15_RoomsPickup  \
# id
# 2017-07-01 - 2017-07-01                  1301.29                    6.0
# 2017-07-01 - 2017-07-02                  -331.36                    2.0
# 2017-07-01 - 2017-07-03                  -318.29                   -2.0
# 2017-07-01 - 2017-07-04                 -1083.03                   -1.0
# 2017-07-01 - 2017-07-05                  -599.38                   -3.0
#
#                          Pace_TM15_ADR_Pickup  Pace_TM15_RevPickup  \
# id
# 2017-07-01 - 2017-07-01                 -0.84               667.38
# 2017-07-01 - 2017-07-02                 -2.10              -110.58
# 2017-07-01 - 2017-07-03                 -4.47             -1070.22
# 2017-07-01 - 2017-07-04                 -2.89              -647.19
# 2017-07-01 - 2017-07-05                 -2.78              -722.09
#
#                          Pace_TM15_TRN_RoomsPickup  Pace_TM15_TRN_ADR_Pickup  \
# id
# 2017-07-01 - 2017-07-01                        8.0                     -1.05
# 2017-07-01 - 2017-07-02                        0.0                     -3.27
# 2017-07-01 - 2017-07-03                        0.0                     -3.90
# 2017-07-01 - 2017-07-04                       -1.0                     -2.21
# 2017-07-01 - 2017-07-05                       -2.0                     -2.08
#
#                          Pace_TM15_TRN_RevPickup  Pace_TM05_RoomsPickup  \
# id
# 2017-07-01 - 2017-07-01                  1023.23                    2.0
# 2017-07-01 - 2017-07-02                  -311.98                   -1.0
# 2017-07-01 - 2017-07-03                  -563.62                    2.0
# 2017-07-01 - 2017-07-04                  -405.59                    1.0
# 2017-07-01 - 2017-07-05                  -357.11                    2.0
#
#                          Pace_TM05_ADR_Pickup  Pace_TM05_RevPickup  \
# id
# 2017-07-01 - 2017-07-01                 -0.36               215.84
# 2017-07-01 - 2017-07-02                  0.09               -44.51
# 2017-07-01 - 2017-07-03                 -0.34               138.00
# 2017-07-01 - 2017-07-04                  0.37               138.00
# 2017-07-01 - 2017-07-05                 -0.53               115.60
#
#                          Pace_TM05_TRN_RoomsPickup  Pace_TM05_TRN_ADR_Pickup  \
# id
# 2017-07-01 - 2017-07-01                        2.0                     -0.77
# 2017-07-01 - 2017-07-02                       -2.0                      0.13
# 2017-07-01 - 2017-07-03                        1.0                     -0.62
# 2017-07-01 - 2017-07-04                        0.0                      0.40
# 2017-07-01 - 2017-07-05                        2.0                     -0.98
#
#                          Pace_TM05_TRN_RevPickup  DemandPrediction
# id
# 2017-07-01 - 2017-07-01                   241.69              -0.0
# 2017-07-01 - 2017-07-02                  -149.91               2.0
# 2017-07-01 - 2017-07-03                    32.60               5.0
# 2017-07-01 - 2017-07-04                    32.60               4.0
# 2017-07-01 - 2017-07-05                   115.60               4.0

# %%
display_cols = [
    "DOW",
    "RemSupply",
    "RemSupply_STLY",
    "OTB_GapToLYA_TRN_RoomsSold",
    "ACTUAL_TRN_RoomsPickup",
    "DemandPrediction"
]
h1_stat_preds[display_cols].head()
# Out:
#                          DOW  RemSupply  RemSupply_STLY  \
# id
# 2017-07-01 - 2017-07-01  Sat       51.0            15.0
# 2017-07-01 - 2017-07-02  Sun       59.0            36.0
# 2017-07-01 - 2017-07-03  Mon       63.0            21.0
# 2017-07-01 - 2017-07-04  Tue       57.0            21.0
# 2017-07-01 - 2017-07-05  Wed       64.0            16.0
#
#                          OTB_GapToLYA_TRN_RoomsSold  ACTUAL_TRN_RoomsPickup  \
# id
# 2017-07-01 - 2017-07-01                        -6.0                     0.0
# 2017-07-01 - 2017-07-02                        -8.0                     3.0
# 2017-07-01 - 2017-07-03                         3.0                     6.0
# 2017-07-01 - 2017-07-04                        -8.0                     4.0
# 2017-07-01 - 2017-07-05                       -17.0                     6.0
#
#                          DemandPrediction
# id
# 2017-07-01 - 2017-07-01              -0.0
# 2017-07-01 - 2017-07-02               2.0
# 2017-07-01 - 2017-07-03               5.0
# 2017-07-01 - 2017-07-04               4.0
# 2017-07-01 - 2017-07-05               4.0

# %%
mean_absolute_error(y_test, preds)
# Out:
# 2.18079090020439

# %%
# plt.subplots(figsize=(14, 14))
title = "Outliers seem to pull line downwards further from arrival."
sns.set(font_scale=1.9)
ax = sns.lmplot(x="DaysUntilArrival", y="DemandPrediction", col='DOW', col_wrap=3, x_jitter=0.5, y_jitter=0.5, data=h1_stat_preds, height=6, aspect=1.2,
               scatter_kws={"color": "#ff9e00"}, line_kws={"color": "#434343"})

# title_font = {
#     "size": 18
# }

# label_font = {
#     "size": 16
# }
# plt.title(title, fontdict=title_font)
# plt.xlabel("Num Days Until Arrival", fontdict=label_font)
# plt.ylabel("Remaining Demand Prediction", fontdict=label_font)
plt.tight_layout()
plt.savefig("../etc/h1_lmplot_dow.jpeg", dpi=200)
plt.show()

# %%
# plt.subplots(figsize=(14, 14))
sns.set_theme("ggplot")
sns.set_style("white")
title = "Outliers seem to pull line downwards further from arrival."

ax = sns.lmplot(x="DaysUntilArrival", y="DemandPrediction", x_jitter=0.5, y_jitter=0.5, data=h1_stat_preds, height=6, aspect=1.2,
               scatter_kws={"color": "#ff9e00"}, line_kws={"color": "#434343"})

title_font = {
    "size": 18
}

label_font = {
    "size": 16
}

plt.title(title, fontdict=title_font)
plt.xlabel("Num Days Until Arrival", fontdict=label_font)
plt.ylabel("Remaining Demand Prediction", fontdict=label_font)
plt.tight_layout()
plt.savefig("../etc/h1_lmplot.jpeg", facecolor='none', dpi=200)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-8be96bafb957> in <module>
#       1 # plt.subplots(figsize=(14, 14))
# ----> 2 sns.set_theme("ggplot")
#       3 sns.set_style("white")
#       4 title = "Outliers seem to pull line downwards further from arrival."
#       5
#
# ~/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/rcmod.py in set_theme(context, style, palette, font, font_scale, color_codes, rc)
#     111
#     112     """
# --> 113     set_context(context, font_scale)
#     114     set_style(style, rc={"font.family": font})
#     115     set_palette(palette, color_codes=color_codes)
#
# ~/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/rcmod.py in set_context(context, font_scale, rc)
#     481
#     482     """
# --> 483     context_object = plotting_context(context, font_scale, rc)
#     484     mpl.rcParams.update(context_object)
#     485
#
# ~/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/rcmod.py in plotting_context(context, font_scale, rc)
#     386         contexts = ["paper", "notebook", "talk", "poster"]
#     387         if context not in contexts:
# --> 388             raise ValueError("context must be in %s" % ", ".join(contexts))
#     389
#     390         # Set up dictionary of default parameters
#
# ValueError: context must be in paper, notebook, talk, poster

# %% [markdown]
# ## Now that we have our model, let's get it in the simulation so we can evaluate our results.
#
# Head over to `demand_model_evaluation.ipynb` for more.
