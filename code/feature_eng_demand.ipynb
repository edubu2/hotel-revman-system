# %% [markdown]
# # Preparing our Dataset to Model Demand

# %%
import os
import pandas as pd
import numpy as np
import datetime
from sklearn.preprocessing import OneHotEncoder as ohe

from dbds import generate_hotel_dfs
from sim import generate_simulation
from model_cancellations import get_otb_res, predict_cancellations
from agg_utils import stly_cols_agg, ly_cols_agg, drop_cols_agg

pd.options.display.max_rows = 150
pd.options.display.max_columns = 250
pd.options.display.max_colwidth = None

DATE_FMT = "%Y-%m-%d"
h1_capacity = 187
h2_capacity = 226
AOD = "2017-08-01"
AOD_dt = pd.to_datetime(AOD)

h1_res = pd.read_pickle("pickle/h1_res.pick")
h2_res = pd.read_pickle("pickle/h2_res.pick")
h1_dbd = pd.read_pickle("pickle/h1_dbd.pick")
h2_dbd = pd.read_pickle("pickle/h2_dbd.pick")

# %%
# h1_res, h1_dbd = generate_hotel_dfs("../data/H1.csv", capacity=h1_capacity)
# h2_res, h2_dbd = generate_hotel_dfs("../data/H2.csv", capacity=h2_capacity)

# h1_res.to_pickle("pickle/h1_res.pick")
# h1_dbd.to_pickle("pickle/h1_dbd.pick")
# h2_res.to_pickle("pickle/h2_res.pick")
# h2_dbd.to_pickle("pickle/h2_dbd.pick")

# %%
# features needed:
features = ["DaysUntilArrival",
"RoomsOTB",
"RevOTB",
"CxlForecast",
"RemSupply",
"SellingPrice",
"STLY_SellingPrice",
"TRN_RoomsOTB",
"TRN_RevOTB",
"TRN_CxlForecast",
"LYA_RoomsSold",
"LYA_ADR",
"LYA_RoomRev",
"WE",
"WD",
"Mon",
"Sat",
"Sun",
"Thu",
"Tue",
"Wed",
"RoomsGapToLYA",
"ADR_GapToLYA",
"TM30_TRN_RoomsPickup",
"TM30_TRN_ADR_Pickup",
"TM30_TRN_RevPickup",
"TM15_RoomsPickup",
"TM15_ADR_Pickup",
"TM15_RevPickup",
"TM15_TRN_RoomsPickup",
"TM15_TRN_ADR_Pickup",
"TM15_TRN_RevPickup",
"TM05_RoomsPickup",
"TM05_ADR_Pickup",
"TM05_RevPickup",
"TM05_TRN_RoomsPickup",
"TM05_TRN_ADR_Pickup",
"TM05_TRN_RevPickup",
"RoomsOTB_Pace",
"ADR_OTB_Pace",
"RevOTB_Pace",
"TRN_RoomsOTB_Pace",
"TRN_ADR_OTB_Pace",
"TRN_RevOTB_Pace",
"TM30_RoomsPickup_Pace",
"TM30_ADR_Pickup_Pace",
"TM30_RevPickup_Pace",
"TM15_RoomsPickup_Pace",
"TM15_ADR_Pickup_Pace",
"TM15_RevPickup_Pace",
"TM05_RoomsPickup_Pace",
"TM05_ADR_Pickup_Pace",
"TM05_RevPickup_Pace",
"TM30_TRN_RoomsPickup_Pace",
"TM30_TRN_ADR_Pickup_Pace",
"TM30_TRN_RevPickup_Pace",
"TM15_TRN_RoomsPickup_Pace",
"TM15_TRN_ADR_Pickup_Pace",
"TM15_TRN_RevPickup_Pace",
"TM05_TRN_RoomsPickup_Pace",
"TM05_TRN_ADR_Pickup_Pace",
"TM05_TRN_RevPickup_Pace",
]

y_col = 'Actual_RoomsSold'

# %% [markdown]
# ## Combine Files Generated by save_sims.py

# %%
# generate list of relevant files
import datetime as dt
hotel_num = 1
h = 'h' + str(hotel_num)
SIM_AOD = pd.to_datetime(dt.date(2017, 8, 1), format=DATE_FMT)
sim_start = SIM_AOD - pd.DateOffset(364) # need exactly 364 days of actuals, the rest future-looking

FOLDER = "./sims/pickle/"
first_date = dt.date(2016, 8, 1)
lam_include = lambda x: x[:2] == h and pd.to_datetime(x[7:17]) >= sim_start
h1_files = [f for f in os.listdir(FOLDER) if lam_include(f)]
h1_files.sort()
len(h1_files), h1_files[0], h1_files[-1] # note STLY date of 8/1/17 == 8/2/16 (matching weekday)
# Out:
# (395, 'h1_sim_2016-08-02.pick', 'h1_sim_2017-08-31.pick')

# %%
# %%time
df_sim = pd.DataFrame()
for otb_data in h1_files:
    df_sim = df_sim.append(pd.read_pickle(FOLDER + otb_data))

df_sim.shape
# Out:
# CPU times: user 2.55 s, sys: 31.9 ms, total: 2.58 s
# Wall time: 2.57 s
# (12144, 53)

# %% [markdown]
# ## Adding calculated features

# %%
# Add AsOfDate

def apply_aod(row):
    stay_date = pd.to_datetime(row["Date"])
    stly_stay_date = pd.to_datetime(row["STLY_Date"])
    n_days_b4 = int(row["DaysUntilArrival"])
    as_of_date = pd.to_datetime(stay_date - pd.DateOffset(n_days_b4), format=DATE_FMT)
    stly_as_of_date = pd.to_datetime(stly_stay_date - pd.DateOffset(n_days_b4), format=DATE_FMT)
    return as_of_date, stly_as_of_date

df_sim[["AsOfDate","STLY_AsOfDate"]] = df_sim[["Date", "STLY_Date", "DaysUntilArrival"]].apply(apply_aod, axis=1, result_type='expand')
df_sim.rename(columns={"Date": "StayDate", "STLY_Date": "STLY_StayDate"}, inplace=True)

df_sim.head()
# Out:
#             DOW  RoomsOTB    RevOTB  CxlForecast  TRN_RoomsOTB  TRN_RevOTB  \
# 2016-08-02  Tue     183.0  31110.89         30.0         159.0    27829.05
# 2016-08-03  Wed     182.0  31660.62         35.0         159.0    28337.88
# 2016-08-04  Thu     181.0  32922.17         35.0         151.0    28013.71
# 2016-08-05  Fri     177.0  33224.35         30.0         143.0    27148.36
# 2016-08-06  Sat     175.0  33130.01         28.0         143.0    27475.32
#
#             TRN_CxlForecast  TRNP_RoomsOTB  TRNP_RevOTB  TRNP_CxlForecast  \
# 2016-08-02             28.0           14.0      2134.60               2.0
# 2016-08-03             31.0           14.0      2162.60               4.0
# 2016-08-04             32.0           20.0      3731.12               3.0
# 2016-08-05             27.0           25.0      5050.29               3.0
# 2016-08-06             25.0           23.0      4628.99               3.0
#
#             GRP_RoomsOTB  GRP_RevOTB  GRP_CxlForecast  CNT_RoomsOTB  \
# 2016-08-02           0.0         0.0              0.0          10.0
# 2016-08-03           1.0       241.0              0.0           8.0
# 2016-08-04           0.0         0.0              0.0          10.0
# 2016-08-05           0.0         0.0              0.0           9.0
# 2016-08-06           0.0         0.0              0.0           9.0
#
#             CNT_RevOTB  CNT_CxlForecast   StayDate     WE     WD  \
# 2016-08-02     1147.24              0.0 2016-08-02  False  False
# 2016-08-03      919.14              0.0 2016-08-03  False  False
# 2016-08-04     1177.34              0.0 2016-08-04  False  False
# 2016-08-05     1025.70              0.0 2016-08-05   True  False
# 2016-08-06     1025.70              0.0 2016-08-06   True  False
#
#            STLY_StayDate  DaysUntilArrival  ADR_OTB  SellingPrice  \
# 2016-08-02    2015-08-04                 0   170.00        178.09
# 2016-08-03    2015-08-05                 1   173.96        181.69
# 2016-08-04    2015-08-06                 2   181.89        187.83
# 2016-08-05    2015-08-07                 3   187.71        193.42
# 2016-08-06    2015-08-08                 4   189.31        195.12
#
#             TM30_RoomsOTB  TM30_RevOTB  TM30_TRN_RoomsOTB  TM30_TRN_RevOTB  \
# 2016-08-02          180.0     29880.26              156.0         26598.42
# 2016-08-03          179.0     30517.59              157.0         27435.85
# 2016-08-04          173.0     30621.96              145.0         26214.16
# 2016-08-05          173.0     31314.92              143.0         26342.59
# 2016-08-06          171.0     31330.05              143.0         26779.02
#
#             TM30_TRNP_RoomsOTB  TM30_TRNP_RevOTB  TM30_GRP_RoomsOTB  \
# 2016-08-02                14.0           2134.60                0.0
# 2016-08-03                14.0           2162.60                0.0
# 2016-08-04                18.0           3230.46                0.0
# 2016-08-05                21.0           3946.63                0.0
# 2016-08-06                19.0           3525.33                0.0
#
#             TM30_GRP_RevOTB  TM30_CNT_RoomsOTB  TM30_CNT_RevOTB  \
# 2016-08-02              0.0               10.0          1147.24
# 2016-08-03              0.0                8.0           919.14
# 2016-08-04              0.0               10.0          1177.34
# 2016-08-05              0.0                9.0          1025.70
# 2016-08-06              0.0                9.0          1025.70
#
#             TM15_RoomsOTB  TM15_RevOTB  TM15_TRN_RoomsOTB  TM15_TRN_RevOTB  \
# 2016-08-02          180.0     30125.10              156.0         26843.26
# 2016-08-03          176.0     30361.96              154.0         27280.22
# 2016-08-04          177.0     31801.65              149.0         27393.85
# 2016-08-05          176.0     32622.33              144.0         27047.00
# 2016-08-06          173.0     32274.77              143.0         27120.74
#
#             TM15_TRNP_RoomsOTB  TM15_TRNP_RevOTB  TM15_GRP_RoomsOTB  \
# 2016-08-02                14.0           2134.60                0.0
# 2016-08-03                14.0           2162.60                0.0
# 2016-08-04                18.0           3230.46                0.0
# 2016-08-05                23.0           4549.63                0.0
# 2016-08-06                21.0           4128.33                0.0
#
#             TM15_GRP_RevOTB  TM15_CNT_RoomsOTB  TM15_CNT_RevOTB  \
# 2016-08-02              0.0               10.0          1147.24
# 2016-08-03              0.0                8.0           919.14
# 2016-08-04              0.0               10.0          1177.34
# 2016-08-05              0.0                9.0          1025.70
# 2016-08-06              0.0                9.0          1025.70
#
#             TM05_RoomsOTB  TM05_RevOTB  TM05_TRN_RoomsOTB  TM05_TRN_RevOTB  \
# 2016-08-02          182.0     30598.64              158.0         27316.80
# 2016-08-03          173.0     29906.87              151.0         26825.13
# 2016-08-04          177.0     31930.67              149.0         27522.87
# 2016-08-05          176.0     32956.31              142.0         26880.32
# 2016-08-06          173.0     32632.90              141.0         26978.21
#
#             TM05_TRNP_RoomsOTB  TM05_TRNP_RevOTB  TM05_GRP_RoomsOTB  \
# 2016-08-02                14.0           2134.60                0.0
# 2016-08-03                14.0           2162.60                0.0
# 2016-08-04                18.0           3230.46                0.0
# 2016-08-05                25.0           5050.29                0.0
# 2016-08-06                23.0           4628.99                0.0
#
#             TM05_GRP_RevOTB  TM05_CNT_RoomsOTB  TM05_CNT_RevOTB   AsOfDate  \
# 2016-08-02              0.0               10.0          1147.24 2016-08-02
# 2016-08-03              0.0                8.0           919.14 2016-08-02
# 2016-08-04              0.0               10.0          1177.34 2016-08-02
# 2016-08-05              0.0                9.0          1025.70 2016-08-02
# 2016-08-06              0.0                9.0          1025.70 2016-08-02
#
#            STLY_AsOfDate
# 2016-08-02    2015-08-04
# 2016-08-03    2015-08-04
# 2016-08-04    2015-08-04
# 2016-08-05    2015-08-04
# 2016-08-06    2015-08-04

# %%
# add remaining supply ('RemSupply')
capacity = 187
df_sim["RemSupply"] = (
    capacity - df_sim.RoomsOTB.astype(int) + df_sim.CxlForecast.astype(int)
)

# %%
# add one-hot-encoded DOW ('Day of Week') columns

ohe_dow = pd.get_dummies(df_sim.DOW, drop_first=True)
dow_ohe_cols = list(ohe_dow.columns)
df_sim[dow_ohe_cols] = ohe_dow

# %%
# add NONTRN cols

df_sim["NONTRN_RoomsOTB"] = (
    df_sim.RoomsOTB - df_sim.TRN_RoomsOTB
)
df_sim["NONTRN_RevOTB"] = df_sim.RevOTB - df_sim.TRN_RevOTB
df_sim["NONTRN_ADR_OTB"] = round(df_sim["NONTRN_RevOTB"] / df_sim["NONTRN_RoomsOTB"], 2)
df_sim["NONTRN_CxlForecast"] = df_sim.CxlForecast - df_sim.TRN_CxlForecast

# df_sim["LYA_NONTRN_RoomsOTB"] = (
#     df_sim.LYA_TRNP_RoomsOTB + df_sim.LYA_GRP_RoomsOTB + df_sim.LYA_CNT_RoomsOTB
# )
# df_sim["LYA_NONTRN_RevOTB"] = df_sim.LYA_TRNP_RevOTB + df_sim.LYA_GRP_RevOTB + df_sim.LYA_CNT_RevOTB

# %%
# Add last-year actual columns ("LYA_")

def apply_ly_cols(row):
    stly_date = row["STLY_StayDate"]
    stly_date_str = datetime.datetime.strftime(stly_date, format=DATE_FMT)

    df_lya = list(h1_dbd.loc[stly_date_str, ly_cols_agg])
    return tuple(df_lya)

ly_new_cols = ["LYA_" + col for col in ly_cols_agg]
df_sim[ly_new_cols] = df_sim[["STLY_StayDate"]].apply(apply_ly_cols, axis=1, result_type="expand")

df_sim.fillna(0, inplace=True)

df_sim.head()
# Out:
#             DOW  RoomsOTB    RevOTB  CxlForecast  TRN_RoomsOTB  TRN_RevOTB  \
# 2016-08-02  Tue     183.0  31110.89         30.0         159.0    27829.05
# 2016-08-03  Wed     182.0  31660.62         35.0         159.0    28337.88
# 2016-08-04  Thu     181.0  32922.17         35.0         151.0    28013.71
# 2016-08-05  Fri     177.0  33224.35         30.0         143.0    27148.36
# 2016-08-06  Sat     175.0  33130.01         28.0         143.0    27475.32
#
#             TRN_CxlForecast  TRNP_RoomsOTB  TRNP_RevOTB  TRNP_CxlForecast  \
# 2016-08-02             28.0           14.0      2134.60               2.0
# 2016-08-03             31.0           14.0      2162.60               4.0
# 2016-08-04             32.0           20.0      3731.12               3.0
# 2016-08-05             27.0           25.0      5050.29               3.0
# 2016-08-06             25.0           23.0      4628.99               3.0
#
#             GRP_RoomsOTB  GRP_RevOTB  GRP_CxlForecast  CNT_RoomsOTB  \
# 2016-08-02           0.0         0.0              0.0          10.0
# 2016-08-03           1.0       241.0              0.0           8.0
# 2016-08-04           0.0         0.0              0.0          10.0
# 2016-08-05           0.0         0.0              0.0           9.0
# 2016-08-06           0.0         0.0              0.0           9.0
#
#             CNT_RevOTB  CNT_CxlForecast   StayDate     WE     WD  \
# 2016-08-02     1147.24              0.0 2016-08-02  False  False
# 2016-08-03      919.14              0.0 2016-08-03  False  False
# 2016-08-04     1177.34              0.0 2016-08-04  False  False
# 2016-08-05     1025.70              0.0 2016-08-05   True  False
# 2016-08-06     1025.70              0.0 2016-08-06   True  False
#
#            STLY_StayDate  DaysUntilArrival  ADR_OTB  SellingPrice  \
# 2016-08-02    2015-08-04                 0   170.00        178.09
# 2016-08-03    2015-08-05                 1   173.96        181.69
# 2016-08-04    2015-08-06                 2   181.89        187.83
# 2016-08-05    2015-08-07                 3   187.71        193.42
# 2016-08-06    2015-08-08                 4   189.31        195.12
#
#             TM30_RoomsOTB  TM30_RevOTB  TM30_TRN_RoomsOTB  TM30_TRN_RevOTB  \
# 2016-08-02          180.0     29880.26              156.0         26598.42
# 2016-08-03          179.0     30517.59              157.0         27435.85
# 2016-08-04          173.0     30621.96              145.0         26214.16
# 2016-08-05          173.0     31314.92              143.0         26342.59
# 2016-08-06          171.0     31330.05              143.0         26779.02
#
#             TM30_TRNP_RoomsOTB  TM30_TRNP_RevOTB  TM30_GRP_RoomsOTB  \
# 2016-08-02                14.0           2134.60                0.0
# 2016-08-03                14.0           2162.60                0.0
# 2016-08-04                18.0           3230.46                0.0
# 2016-08-05                21.0           3946.63                0.0
# 2016-08-06                19.0           3525.33                0.0
#
#             TM30_GRP_RevOTB  TM30_CNT_RoomsOTB  TM30_CNT_RevOTB  \
# 2016-08-02              0.0               10.0          1147.24
# 2016-08-03              0.0                8.0           919.14
# 2016-08-04              0.0               10.0          1177.34
# 2016-08-05              0.0                9.0          1025.70
# 2016-08-06              0.0                9.0          1025.70
#
#             TM15_RoomsOTB  TM15_RevOTB  TM15_TRN_RoomsOTB  TM15_TRN_RevOTB  \
# 2016-08-02          180.0     30125.10              156.0         26843.26
# 2016-08-03          176.0     30361.96              154.0         27280.22
# 2016-08-04          177.0     31801.65              149.0         27393.85
# 2016-08-05          176.0     32622.33              144.0         27047.00
# 2016-08-06          173.0     32274.77              143.0         27120.74
#
#             TM15_TRNP_RoomsOTB  TM15_TRNP_RevOTB  TM15_GRP_RoomsOTB  \
# 2016-08-02                14.0           2134.60                0.0
# 2016-08-03                14.0           2162.60                0.0
# 2016-08-04                18.0           3230.46                0.0
# 2016-08-05                23.0           4549.63                0.0
# 2016-08-06                21.0           4128.33                0.0
#
#             TM15_GRP_RevOTB  TM15_CNT_RoomsOTB  TM15_CNT_RevOTB  \
# 2016-08-02              0.0               10.0          1147.24
# 2016-08-03              0.0                8.0           919.14
# 2016-08-04              0.0               10.0          1177.34
# 2016-08-05              0.0                9.0          1025.70
# 2016-08-06              0.0                9.0          1025.70
#
#             TM05_RoomsOTB  TM05_RevOTB  TM05_TRN_RoomsOTB  TM05_TRN_RevOTB  \
# 2016-08-02          182.0     30598.64              158.0         27316.80
# 2016-08-03          173.0     29906.87              151.0         26825.13
# 2016-08-04          177.0     31930.67              149.0         27522.87
# 2016-08-05          176.0     32956.31              142.0         26880.32
# 2016-08-06          173.0     32632.90              141.0         26978.21
#
#             TM05_TRNP_RoomsOTB  TM05_TRNP_RevOTB  TM05_GRP_RoomsOTB  \
# 2016-08-02                14.0           2134.60                0.0
# 2016-08-03                14.0           2162.60                0.0
# 2016-08-04                18.0           3230.46                0.0
# 2016-08-05                25.0           5050.29                0.0
# 2016-08-06                23.0           4628.99                0.0
#
#             TM05_GRP_RevOTB  TM05_CNT_RoomsOTB  TM05_CNT_RevOTB   AsOfDate  \
# 2016-08-02              0.0               10.0          1147.24 2016-08-02
# 2016-08-03              0.0                8.0           919.14 2016-08-02
# 2016-08-04              0.0               10.0          1177.34 2016-08-02
# 2016-08-05              0.0                9.0          1025.70 2016-08-02
# 2016-08-06              0.0                9.0          1025.70 2016-08-02
#
#            STLY_AsOfDate  RemSupply  Mon  Sat  Sun  Thu  Tue  Wed  \
# 2016-08-02    2015-08-04         34    0    0    0    0    1    0
# 2016-08-03    2015-08-04         40    0    0    0    0    0    1
# 2016-08-04    2015-08-04         41    0    0    0    1    0    0
# 2016-08-05    2015-08-04         40    0    0    0    0    0    0
# 2016-08-06    2015-08-04         40    0    1    0    0    0    0
#
#             NONTRN_RoomsOTB  NONTRN_RevOTB  NONTRN_ADR_OTB  \
# 2016-08-02             24.0        3281.84          136.74
# 2016-08-03             23.0        3322.74          144.47
# 2016-08-04             30.0        4908.46          163.62
# 2016-08-05             34.0        6075.99          178.71
# 2016-08-06             32.0        5654.69          176.71
#
#             NONTRN_CxlForecast  LYA_RoomsSold  LYA_ADR  LYA_RoomRev  \
# 2016-08-02                 2.0          182.0   151.57     27585.83
# 2016-08-03                 4.0          182.0   152.92     27831.73
# 2016-08-04                 3.0          180.0   155.27     27947.92
# 2016-08-05                 3.0          182.0   153.31     27901.89
# 2016-08-06                 3.0          181.0   156.18     28269.01
#
#             LYA_NumCancels  LYA_TRN_RoomsSold  LYA_TRN_ADR  LYA_TRN_RoomRev
# 2016-08-02            58.0              132.0       164.59         21725.78
# 2016-08-03            59.0              137.0       164.13         22485.30
# 2016-08-04            57.0              137.0       166.14         22760.64
# 2016-08-05            59.0              139.0       163.06         22665.76
# 2016-08-06            63.0              140.0       167.90         23505.41

# %%
# get recent pickup (tminus) columns


# first need TRN_ADR

df_sim["TRN_ADR_OTB"] = round(df_sim["TRN_RevOTB"] / df_sim["TRN_RoomsOTB"])

# loop thru tminus windows (for total hotel & trn) & count bookings
tms = ["TM30_", "TM15_", "TM05_"]
segs = ["", "TRN_"] # "" for total hotel
# df_sim.drop(
#     columns=["TM30_Date", "TM15_Date", "TM05_Date"], inplace=True, errors="ignore"
# )

for tm in tms:
    for seg in segs:
        
        # add tm_seg_adr
        df_sim[tm + seg + "ADR_OTB"] = round(df_sim[tm + seg + "RevOTB"] / df_sim[tm + seg + "RoomsOTB"], 2)
        # and now segmented stats
        df_sim[tm + seg + "RoomsPickup"] = round(
            df_sim[seg + "RoomsOTB"] - df_sim[tm + seg + "RoomsOTB"], 2
        )
        df_sim[tm + seg + "RevPickup"] = round(
            df_sim[seg + "RevOTB"] - df_sim[tm + seg + "RevOTB"], 2
        )
        df_sim[tm + seg + "ADR_Pickup"] = round(
            df_sim[seg + "ADR_OTB"] - df_sim[tm + seg + "ADR_OTB"], 2
        )


    # back to outside loop (iterating thru tms)
    # add TM_NONTRN_OTB
    df_sim[tm +  "NONTRN_RoomsOTB"] = (
        df_sim[tm + "RoomsOTB"]
        - df_sim[tm + "TRN_RoomsOTB"]
    )
    df_sim[tm + "NONTRN_RevOTB"] = (
        df_sim[tm + "RevOTB"]
        - df_sim[tm + "TRN_RevOTB"]
    )
    df_sim[tm + "NONTRN_ADR_OTB"] = round(
        df_sim[tm + "NONTRN_RevOTB"] / df_sim[tm + "NONTRN_RoomsOTB"], 2
    )
    # add TM_NONTRN_OTB Pickup
    df_sim[tm +  "NONTRN_RoomsPickup"] = (
        df_sim["NONTRN_RoomsOTB"]
        - df_sim[tm + "NONTRN_RoomsOTB"]
    )
    df_sim[tm + "NONTRN_RevPickup"] = (
        df_sim["NONTRN_RevOTB"]
        - df_sim[tm + "NONTRN_RevOTB"]
    )
    df_sim[tm + "NONTRN_ADR_Pickup"] = (
        df_sim["NONTRN_ADR_OTB"]
        - df_sim[tm + "NONTRN_ADR_OTB"]
    )

df_sim.head()
# Out:
#             DOW  RoomsOTB    RevOTB  CxlForecast  TRN_RoomsOTB  TRN_RevOTB  \
# 2016-08-02  Tue     183.0  31110.89         30.0         159.0    27829.05
# 2016-08-03  Wed     182.0  31660.62         35.0         159.0    28337.88
# 2016-08-04  Thu     181.0  32922.17         35.0         151.0    28013.71
# 2016-08-05  Fri     177.0  33224.35         30.0         143.0    27148.36
# 2016-08-06  Sat     175.0  33130.01         28.0         143.0    27475.32
#
#             TRN_CxlForecast  TRNP_RoomsOTB  TRNP_RevOTB  TRNP_CxlForecast  \
# 2016-08-02             28.0           14.0      2134.60               2.0
# 2016-08-03             31.0           14.0      2162.60               4.0
# 2016-08-04             32.0           20.0      3731.12               3.0
# 2016-08-05             27.0           25.0      5050.29               3.0
# 2016-08-06             25.0           23.0      4628.99               3.0
#
#             GRP_RoomsOTB  GRP_RevOTB  GRP_CxlForecast  CNT_RoomsOTB  \
# 2016-08-02           0.0         0.0              0.0          10.0
# 2016-08-03           1.0       241.0              0.0           8.0
# 2016-08-04           0.0         0.0              0.0          10.0
# 2016-08-05           0.0         0.0              0.0           9.0
# 2016-08-06           0.0         0.0              0.0           9.0
#
#             CNT_RevOTB  CNT_CxlForecast   StayDate     WE     WD  \
# 2016-08-02     1147.24              0.0 2016-08-02  False  False
# 2016-08-03      919.14              0.0 2016-08-03  False  False
# 2016-08-04     1177.34              0.0 2016-08-04  False  False
# 2016-08-05     1025.70              0.0 2016-08-05   True  False
# 2016-08-06     1025.70              0.0 2016-08-06   True  False
#
#            STLY_StayDate  DaysUntilArrival  ADR_OTB  SellingPrice  \
# 2016-08-02    2015-08-04                 0   170.00        178.09
# 2016-08-03    2015-08-05                 1   173.96        181.69
# 2016-08-04    2015-08-06                 2   181.89        187.83
# 2016-08-05    2015-08-07                 3   187.71        193.42
# 2016-08-06    2015-08-08                 4   189.31        195.12
#
#             TM30_RoomsOTB  TM30_RevOTB  TM30_TRN_RoomsOTB  TM30_TRN_RevOTB  \
# 2016-08-02          180.0     29880.26              156.0         26598.42
# 2016-08-03          179.0     30517.59              157.0         27435.85
# 2016-08-04          173.0     30621.96              145.0         26214.16
# 2016-08-05          173.0     31314.92              143.0         26342.59
# 2016-08-06          171.0     31330.05              143.0         26779.02
#
#             TM30_TRNP_RoomsOTB  TM30_TRNP_RevOTB  TM30_GRP_RoomsOTB  \
# 2016-08-02                14.0           2134.60                0.0
# 2016-08-03                14.0           2162.60                0.0
# 2016-08-04                18.0           3230.46                0.0
# 2016-08-05                21.0           3946.63                0.0
# 2016-08-06                19.0           3525.33                0.0
#
#             TM30_GRP_RevOTB  TM30_CNT_RoomsOTB  TM30_CNT_RevOTB  \
# 2016-08-02              0.0               10.0          1147.24
# 2016-08-03              0.0                8.0           919.14
# 2016-08-04              0.0               10.0          1177.34
# 2016-08-05              0.0                9.0          1025.70
# 2016-08-06              0.0                9.0          1025.70
#
#             TM15_RoomsOTB  TM15_RevOTB  TM15_TRN_RoomsOTB  TM15_TRN_RevOTB  \
# 2016-08-02          180.0     30125.10              156.0         26843.26
# 2016-08-03          176.0     30361.96              154.0         27280.22
# 2016-08-04          177.0     31801.65              149.0         27393.85
# 2016-08-05          176.0     32622.33              144.0         27047.00
# 2016-08-06          173.0     32274.77              143.0         27120.74
#
#             TM15_TRNP_RoomsOTB  TM15_TRNP_RevOTB  TM15_GRP_RoomsOTB  \
# 2016-08-02                14.0           2134.60                0.0
# 2016-08-03                14.0           2162.60                0.0
# 2016-08-04                18.0           3230.46                0.0
# 2016-08-05                23.0           4549.63                0.0
# 2016-08-06                21.0           4128.33                0.0
#
#             TM15_GRP_RevOTB  TM15_CNT_RoomsOTB  TM15_CNT_RevOTB  \
# 2016-08-02              0.0               10.0          1147.24
# 2016-08-03              0.0                8.0           919.14
# 2016-08-04              0.0               10.0          1177.34
# 2016-08-05              0.0                9.0          1025.70
# 2016-08-06              0.0                9.0          1025.70
#
#             TM05_RoomsOTB  TM05_RevOTB  TM05_TRN_RoomsOTB  TM05_TRN_RevOTB  \
# 2016-08-02          182.0     30598.64              158.0         27316.80
# 2016-08-03          173.0     29906.87              151.0         26825.13
# 2016-08-04          177.0     31930.67              149.0         27522.87
# 2016-08-05          176.0     32956.31              142.0         26880.32
# 2016-08-06          173.0     32632.90              141.0         26978.21
#
#             TM05_TRNP_RoomsOTB  TM05_TRNP_RevOTB  TM05_GRP_RoomsOTB  \
# 2016-08-02                14.0           2134.60                0.0
# 2016-08-03                14.0           2162.60                0.0
# 2016-08-04                18.0           3230.46                0.0
# 2016-08-05                25.0           5050.29                0.0
# 2016-08-06                23.0           4628.99                0.0
#
#             TM05_GRP_RevOTB  TM05_CNT_RoomsOTB  TM05_CNT_RevOTB   AsOfDate  \
# 2016-08-02              0.0               10.0          1147.24 2016-08-02
# 2016-08-03              0.0                8.0           919.14 2016-08-02
# 2016-08-04              0.0               10.0          1177.34 2016-08-02
# 2016-08-05              0.0                9.0          1025.70 2016-08-02
# 2016-08-06              0.0                9.0          1025.70 2016-08-02
#
#            STLY_AsOfDate  RemSupply  Mon  Sat  Sun  Thu  Tue  Wed  \
# 2016-08-02    2015-08-04         34    0    0    0    0    1    0
# 2016-08-03    2015-08-04         40    0    0    0    0    0    1
# 2016-08-04    2015-08-04         41    0    0    0    1    0    0
# 2016-08-05    2015-08-04         40    0    0    0    0    0    0
# 2016-08-06    2015-08-04         40    0    1    0    0    0    0
#
#             NONTRN_RoomsOTB  NONTRN_RevOTB  NONTRN_ADR_OTB  \
# 2016-08-02             24.0        3281.84          136.74
# 2016-08-03             23.0        3322.74          144.47
# 2016-08-04             30.0        4908.46          163.62
# 2016-08-05             34.0        6075.99          178.71
# 2016-08-06             32.0        5654.69          176.71
#
#             NONTRN_CxlForecast  LYA_RoomsSold  LYA_ADR  LYA_RoomRev  \
# 2016-08-02                 2.0          182.0   151.57     27585.83
# 2016-08-03                 4.0          182.0   152.92     27831.73
# 2016-08-04                 3.0          180.0   155.27     27947.92
# 2016-08-05                 3.0          182.0   153.31     27901.89
# 2016-08-06                 3.0          181.0   156.18     28269.01
#
#             LYA_NumCancels  LYA_TRN_RoomsSold  LYA_TRN_ADR  LYA_TRN_RoomRev  \
# 2016-08-02            58.0              132.0       164.59         21725.78
# 2016-08-03            59.0              137.0       164.13         22485.30
# 2016-08-04            57.0              137.0       166.14         22760.64
# 2016-08-05            59.0              139.0       163.06         22665.76
# 2016-08-06            63.0              140.0       167.90         23505.41
#
#             TRN_ADR_OTB  TM30_ADR_OTB  TM30_RoomsPickup  TM30_RevPickup  \
# 2016-08-02        175.0        166.00               3.0         1230.63
# 2016-08-03        178.0        170.49               3.0         1143.03
# 2016-08-04        186.0        177.01               8.0         2300.21
# 2016-08-05        190.0        181.01               4.0         1909.43
# 2016-08-06        192.0        183.22               4.0         1799.96
#
#             TM30_ADR_Pickup  TM30_TRN_ADR_OTB  TM30_TRN_RoomsPickup  \
# 2016-08-02             4.00            170.50                   3.0
# 2016-08-03             3.47            174.75                   2.0
# 2016-08-04             4.88            180.79                   6.0
# 2016-08-05             6.70            184.21                   0.0
# 2016-08-06             6.09            187.27                   0.0
#
#             TM30_TRN_RevPickup  TM30_TRN_ADR_Pickup  TM30_NONTRN_RoomsOTB  \
# 2016-08-02             1230.63                 4.50                  24.0
# 2016-08-03              902.03                 3.25                  22.0
# 2016-08-04             1799.55                 5.21                  28.0
# 2016-08-05              805.77                 5.79                  30.0
# 2016-08-06              696.30                 4.73                  28.0
#
#             TM30_NONTRN_RevOTB  TM30_NONTRN_ADR_OTB  TM30_NONTRN_RoomsPickup  \
# 2016-08-02             3281.84               136.74                      0.0
# 2016-08-03             3081.74               140.08                      1.0
# 2016-08-04             4407.80               157.42                      2.0
# 2016-08-05             4972.33               165.74                      4.0
# 2016-08-06             4551.03               162.54                      4.0
#
#             TM30_NONTRN_RevPickup  TM30_NONTRN_ADR_Pickup  TM15_ADR_OTB  \
# 2016-08-02           1.818989e-11                    0.00        167.36
# 2016-08-03           2.410000e+02                    4.39        172.51
# 2016-08-04           5.006600e+02                    6.20        179.67
# 2016-08-05           1.103660e+03                   12.97        185.35
# 2016-08-06           1.103660e+03                   14.17        186.56
#
#             TM15_RoomsPickup  TM15_RevPickup  TM15_ADR_Pickup  \
# 2016-08-02               3.0          985.79             2.64
# 2016-08-03               6.0         1298.66             1.45
# 2016-08-04               4.0         1120.52             2.22
# 2016-08-05               1.0          602.02             2.36
# 2016-08-06               2.0          855.24             2.75
#
#             TM15_TRN_ADR_OTB  TM15_TRN_RoomsPickup  TM15_TRN_RevPickup  \
# 2016-08-02            172.07                   3.0              985.79
# 2016-08-03            177.14                   5.0             1057.66
# 2016-08-04            183.85                   2.0              619.86
# 2016-08-05            187.83                  -1.0              101.36
# 2016-08-06            189.66                   0.0              354.58
#
#             TM15_TRN_ADR_Pickup  TM15_NONTRN_RoomsOTB  TM15_NONTRN_RevOTB  \
# 2016-08-02                 2.93                  24.0             3281.84
# 2016-08-03                 0.86                  22.0             3081.74
# 2016-08-04                 2.15                  28.0             4407.80
# 2016-08-05                 2.17                  32.0             5575.33
# 2016-08-06                 2.34                  30.0             5154.03
#
#             TM15_NONTRN_ADR_OTB  TM15_NONTRN_RoomsPickup  \
# 2016-08-02               136.74                      0.0
# 2016-08-03               140.08                      1.0
# 2016-08-04               157.42                      2.0
# 2016-08-05               174.23                      2.0
# 2016-08-06               171.80                      2.0
#
#             TM15_NONTRN_RevPickup  TM15_NONTRN_ADR_Pickup  TM05_ADR_OTB  \
# 2016-08-02           1.818989e-11                    0.00        168.12
# 2016-08-03           2.410000e+02                    4.39        172.87
# 2016-08-04           5.006600e+02                    6.20        180.40
# 2016-08-05           5.006600e+02                    4.48        187.25
# 2016-08-06           5.006600e+02                    4.91        188.63
#
#             TM05_RoomsPickup  TM05_RevPickup  TM05_ADR_Pickup  \
# 2016-08-02               1.0          512.25             1.88
# 2016-08-03               9.0         1753.75             1.09
# 2016-08-04               4.0          991.50             1.49
# 2016-08-05               1.0          268.04             0.46
# 2016-08-06               2.0          497.11             0.68
#
#             TM05_TRN_ADR_OTB  TM05_TRN_RoomsPickup  TM05_TRN_RevPickup  \
# 2016-08-02            172.89                   1.0              512.25
# 2016-08-03            177.65                   8.0             1512.75
# 2016-08-04            184.72                   2.0              490.84
# 2016-08-05            189.30                   1.0              268.04
# 2016-08-06            191.33                   2.0              497.11
#
#             TM05_TRN_ADR_Pickup  TM05_NONTRN_RoomsOTB  TM05_NONTRN_RevOTB  \
# 2016-08-02                 2.11                  24.0             3281.84
# 2016-08-03                 0.35                  22.0             3081.74
# 2016-08-04                 1.28                  28.0             4407.80
# 2016-08-05                 0.70                  34.0             6075.99
# 2016-08-06                 0.67                  32.0             5654.69
#
#             TM05_NONTRN_ADR_OTB  TM05_NONTRN_RoomsPickup  \
# 2016-08-02               136.74                      0.0
# 2016-08-03               140.08                      1.0
# 2016-08-04               157.42                      2.0
# 2016-08-05               178.71                      0.0
# 2016-08-06               176.71                      0.0
#
#             TM05_NONTRN_RevPickup  TM05_NONTRN_ADR_Pickup
# 2016-08-02           1.818989e-11                    0.00
# 2016-08-03           2.410000e+02                    4.39
# 2016-08-04           5.006600e+02                    6.20
# 2016-08-05           2.182787e-11                    0.00
# 2016-08-06          -3.637979e-12                    0.00

# %%
# add gap to LYA columns (by segment)
# must be done AFTER NONTRN cols added
df_sim["RoomsGapToLYA"] = df_sim.LYA_RoomsSold - df_sim.RoomsOTB
df_sim["RevGapToLYA"] = df_sim.LYA_RoomRev - df_sim.RevOTB
df_sim["ADR_GapToLYA"] = df_sim.LYA_ADR - df_sim.ADR_OTB

df_sim["TRN_RoomsGapToLYA"] = df_sim.LYA_TRN_RoomsSold - df_sim.TRN_RoomsOTB
df_sim["TRN_RevGapToLYA"] = df_sim.LYA_TRN_RoomRev - df_sim.TRN_RevOTB
df_sim["TRN_ADR_GapToLYA"] = df_sim.LYA_TRN_ADR - df_sim.TRN_ADR_OTB

df_sim["NONTRN_RoomsGapToLYA"] = df_sim["RoomsGapToLYA"] - df_sim["TRN_RoomsGapToLYA"]
df_sim["NONTRN_RevGapToLYA"] = df_sim["RevGapToLYA"] - df_sim["TRN_RevGapToLYA"]
df_sim["NONTRN_ADR_GapToLYA"] = df_sim["ADR_GapToLYA"] - df_sim["TRN_ADR_GapToLYA"]

# %%
df_sim.columns
# Out:
# Index(['DOW', 'RoomsOTB', 'RevOTB', 'CxlForecast', 'TRN_RoomsOTB',
#        'TRN_RevOTB', 'TRN_CxlForecast', 'TRNP_RoomsOTB', 'TRNP_RevOTB',
#        'TRNP_CxlForecast',
#        ...
#        'TM05_NONTRN_ADR_Pickup', 'RoomsGapToLYA', 'RevGapToLYA',
#        'ADR_GapToLYA', 'TRN_RoomsGapToLYA', 'TRN_RevGapToLYA',
#        'TRN_ADR_GapToLYA', 'NONTRN_RoomsGapToLYA', 'NONTRN_RevGapToLYA',
#        'NONTRN_ADR_GapToLYA'],
#       dtype='object', length=125)

# %%
# remove all non-gap, non-pickup actual/tminus columns
# I will want to move this down in our script to combine with removing stly cols (we only want pace)
# removing them here just to make it cleaner

df_sim.drop(columns=drop_cols_agg, inplace=True, errors='ignore')
df_sim.columns
# Out:
# Index(['DOW', 'RoomsOTB', 'RevOTB', 'CxlForecast', 'TRN_RoomsOTB',
#        'TRN_RevOTB', 'TRN_CxlForecast', 'StayDate', 'WE', 'WD',
#        'STLY_StayDate', 'DaysUntilArrival', 'ADR_OTB', 'SellingPrice',
#        'AsOfDate', 'STLY_AsOfDate', 'RemSupply', 'Mon', 'Sat', 'Sun', 'Thu',
#        'Tue', 'Wed', 'NONTRN_RoomsOTB', 'NONTRN_RevOTB', 'NONTRN_ADR_OTB',
#        'NONTRN_CxlForecast', 'TRN_ADR_OTB', 'TM30_RoomsPickup',
#        'TM30_RevPickup', 'TM30_ADR_Pickup', 'TM30_TRN_RoomsPickup',
#        'TM30_TRN_RevPickup', 'TM30_TRN_ADR_Pickup', 'TM30_NONTRN_RoomsPickup',
#        'TM30_NONTRN_RevPickup', 'TM30_NONTRN_ADR_Pickup', 'TM15_RoomsPickup',
#        'TM15_RevPickup', 'TM15_ADR_Pickup', 'TM15_TRN_RoomsPickup',
#        'TM15_TRN_RevPickup', 'TM15_TRN_ADR_Pickup', 'TM15_NONTRN_RoomsPickup',
#        'TM15_NONTRN_RevPickup', 'TM15_NONTRN_ADR_Pickup', 'TM05_RoomsPickup',
#        'TM05_RevPickup', 'TM05_ADR_Pickup', 'TM05_TRN_RoomsPickup',
#        'TM05_TRN_RevPickup', 'TM05_TRN_ADR_Pickup', 'TM05_NONTRN_RoomsPickup',
#        'TM05_NONTRN_RevPickup', 'TM05_NONTRN_ADR_Pickup', 'RoomsGapToLYA',
#        'RevGapToLYA', 'ADR_GapToLYA', 'TRN_RoomsGapToLYA', 'TRN_RevGapToLYA',
#        'TRN_ADR_GapToLYA', 'NONTRN_RoomsGapToLYA', 'NONTRN_RevGapToLYA',
#        'NONTRN_ADR_GapToLYA'],
#       dtype='object')

# %% [markdown]
# # EW- NEXT STEPS (THU 5PM)
#
# 1. drop unneeded, post-processed TM_nn columns in blank cell above (create list in agg_utils.py)
# 2. pull stly cols via merge below
# 3. calculate pace
# 4. drop unneeded, post-processed stly cols
# 5. add all of the steps in this notebook to agg.py
# 6. pull features from list at top of this NB
# 7. train/test split
# 8. linear regression (predict RoomsSold)
# 9. randomForest (predict RoomsSold)

# %% [markdown]
# **Time to pull STLY columns. I will accomplish this by merging df_sim on top of itself and pulling the below columns into the next year's row with the `'STLY_'` prefix.***
#
# But before we do that, let's make sure we add in the ADR columns.
#
# NEVERMIND - THIS STEP NEEDS TO COME LAST ONCE WE HAVE ALL OF THE OTHER COLUMNS

# %%
df_sim.head(2)
# Out:
#             DOW  RoomsOTB    RevOTB  CxlForecast  TRN_RoomsOTB  TRN_RevOTB  \
# 2016-08-02  Tue     183.0  31110.89         30.0         159.0    27829.05
# 2016-08-03  Wed     182.0  31660.62         35.0         159.0    28337.88
#
#             TRN_CxlForecast   StayDate     WE     WD STLY_StayDate  \
# 2016-08-02             28.0 2016-08-02  False  False    2015-08-04
# 2016-08-03             31.0 2016-08-03  False  False    2015-08-05
#
#             DaysUntilArrival  ADR_OTB  SellingPrice   AsOfDate STLY_AsOfDate  \
# 2016-08-02                 0   170.00        178.09 2016-08-02    2015-08-04
# 2016-08-03                 1   173.96        181.69 2016-08-02    2015-08-04
#
#             RemSupply  Mon  Sat  Sun  Thu  Tue  Wed  NONTRN_RoomsOTB  \
# 2016-08-02         34    0    0    0    0    1    0             24.0
# 2016-08-03         40    0    0    0    0    0    1             23.0
#
#             NONTRN_RevOTB  NONTRN_ADR_OTB  NONTRN_CxlForecast  TRN_ADR_OTB  \
# 2016-08-02        3281.84          136.74                 2.0        175.0
# 2016-08-03        3322.74          144.47                 4.0        178.0
#
#             TM30_RoomsPickup  TM30_RevPickup  TM30_ADR_Pickup  \
# 2016-08-02               3.0         1230.63             4.00
# 2016-08-03               3.0         1143.03             3.47
#
#             TM30_TRN_RoomsPickup  TM30_TRN_RevPickup  TM30_TRN_ADR_Pickup  \
# 2016-08-02                   3.0             1230.63                 4.50
# 2016-08-03                   2.0              902.03                 3.25
#
#             TM30_NONTRN_RoomsPickup  TM30_NONTRN_RevPickup  \
# 2016-08-02                      0.0           1.818989e-11
# 2016-08-03                      1.0           2.410000e+02
#
#             TM30_NONTRN_ADR_Pickup  TM15_RoomsPickup  TM15_RevPickup  \
# 2016-08-02                    0.00               3.0          985.79
# 2016-08-03                    4.39               6.0         1298.66
#
#             TM15_ADR_Pickup  TM15_TRN_RoomsPickup  TM15_TRN_RevPickup  \
# 2016-08-02             2.64                   3.0              985.79
# 2016-08-03             1.45                   5.0             1057.66
#
#             TM15_TRN_ADR_Pickup  TM15_NONTRN_RoomsPickup  \
# 2016-08-02                 2.93                      0.0
# 2016-08-03                 0.86                      1.0
#
#             TM15_NONTRN_RevPickup  TM15_NONTRN_ADR_Pickup  TM05_RoomsPickup  \
# 2016-08-02           1.818989e-11                    0.00               1.0
# 2016-08-03           2.410000e+02                    4.39               9.0
#
#             TM05_RevPickup  TM05_ADR_Pickup  TM05_TRN_RoomsPickup  \
# 2016-08-02          512.25             1.88                   1.0
# 2016-08-03         1753.75             1.09                   8.0
#
#             TM05_TRN_RevPickup  TM05_TRN_ADR_Pickup  TM05_NONTRN_RoomsPickup  \
# 2016-08-02              512.25                 2.11                      0.0
# 2016-08-03             1512.75                 0.35                      1.0
#
#             TM05_NONTRN_RevPickup  TM05_NONTRN_ADR_Pickup  RoomsGapToLYA  \
# 2016-08-02           1.818989e-11                    0.00           -1.0
# 2016-08-03           2.410000e+02                    4.39            0.0
#
#             RevGapToLYA  ADR_GapToLYA  TRN_RoomsGapToLYA  TRN_RevGapToLYA  \
# 2016-08-02     -3525.06        -18.43              -27.0         -6103.27
# 2016-08-03     -3828.89        -21.04              -22.0         -5852.58
#
#             TRN_ADR_GapToLYA  NONTRN_RoomsGapToLYA  NONTRN_RevGapToLYA  \
# 2016-08-02            -10.41                  26.0             2578.21
# 2016-08-03            -13.87                  22.0             2023.69
#
#             NONTRN_ADR_GapToLYA
# 2016-08-02                -8.02
# 2016-08-03                -7.17

# %%
# pull STLY columns with self-merge to STLY date

# first, we need to create unique ID col (id) for each as-of-date/stay-date combo
# then, we manipulate strings to add a stly_id column that we can use as right key for our merge

df_sim_ids = df_sim.AsOfDate.astype(str) + ' - ' + df_sim.StayDate.astype(str)
df_sim.insert(0, "id", df_sim_ids)

df_sim_stly_ids = df_sim.STLY_AsOfDate.astype(str) + ' - ' + df_sim.STLY_StayDate.astype(str)
df_sim.insert(1, "stly_id", df_sim_stly_ids)
df_sim.head()
# Out:
#                                  id                  stly_id  DOW  RoomsOTB  \
# 2016-08-02  2016-08-02 - 2016-08-02  2015-08-04 - 2015-08-04  Tue     183.0
# 2016-08-03  2016-08-02 - 2016-08-03  2015-08-04 - 2015-08-05  Wed     182.0
# 2016-08-04  2016-08-02 - 2016-08-04  2015-08-04 - 2015-08-06  Thu     181.0
# 2016-08-05  2016-08-02 - 2016-08-05  2015-08-04 - 2015-08-07  Fri     177.0
# 2016-08-06  2016-08-02 - 2016-08-06  2015-08-04 - 2015-08-08  Sat     175.0
#
#               RevOTB  CxlForecast  TRN_RoomsOTB  TRN_RevOTB  TRN_CxlForecast  \
# 2016-08-02  31110.89         30.0         159.0    27829.05             28.0
# 2016-08-03  31660.62         35.0         159.0    28337.88             31.0
# 2016-08-04  32922.17         35.0         151.0    28013.71             32.0
# 2016-08-05  33224.35         30.0         143.0    27148.36             27.0
# 2016-08-06  33130.01         28.0         143.0    27475.32             25.0
#
#              StayDate     WE     WD STLY_StayDate  DaysUntilArrival  ADR_OTB  \
# 2016-08-02 2016-08-02  False  False    2015-08-04                 0   170.00
# 2016-08-03 2016-08-03  False  False    2015-08-05                 1   173.96
# 2016-08-04 2016-08-04  False  False    2015-08-06                 2   181.89
# 2016-08-05 2016-08-05   True  False    2015-08-07                 3   187.71
# 2016-08-06 2016-08-06   True  False    2015-08-08                 4   189.31
#
#             SellingPrice   AsOfDate STLY_AsOfDate  RemSupply  Mon  Sat  Sun  \
# 2016-08-02        178.09 2016-08-02    2015-08-04         34    0    0    0
# 2016-08-03        181.69 2016-08-02    2015-08-04         40    0    0    0
# 2016-08-04        187.83 2016-08-02    2015-08-04         41    0    0    0
# 2016-08-05        193.42 2016-08-02    2015-08-04         40    0    0    0
# 2016-08-06        195.12 2016-08-02    2015-08-04         40    0    1    0
#
#             Thu  Tue  Wed  NONTRN_RoomsOTB  NONTRN_RevOTB  NONTRN_ADR_OTB  \
# 2016-08-02    0    1    0             24.0        3281.84          136.74
# 2016-08-03    0    0    1             23.0        3322.74          144.47
# 2016-08-04    1    0    0             30.0        4908.46          163.62
# 2016-08-05    0    0    0             34.0        6075.99          178.71
# 2016-08-06    0    0    0             32.0        5654.69          176.71
#
#             NONTRN_CxlForecast  TRN_ADR_OTB  TM30_RoomsPickup  TM30_RevPickup  \
# 2016-08-02                 2.0        175.0               3.0         1230.63
# 2016-08-03                 4.0        178.0               3.0         1143.03
# 2016-08-04                 3.0        186.0               8.0         2300.21
# 2016-08-05                 3.0        190.0               4.0         1909.43
# 2016-08-06                 3.0        192.0               4.0         1799.96
#
#             TM30_ADR_Pickup  TM30_TRN_RoomsPickup  TM30_TRN_RevPickup  \
# 2016-08-02             4.00                   3.0             1230.63
# 2016-08-03             3.47                   2.0              902.03
# 2016-08-04             4.88                   6.0             1799.55
# 2016-08-05             6.70                   0.0              805.77
# 2016-08-06             6.09                   0.0              696.30
#
#             TM30_TRN_ADR_Pickup  TM30_NONTRN_RoomsPickup  \
# 2016-08-02                 4.50                      0.0
# 2016-08-03                 3.25                      1.0
# 2016-08-04                 5.21                      2.0
# 2016-08-05                 5.79                      4.0
# 2016-08-06                 4.73                      4.0
#
#             TM30_NONTRN_RevPickup  TM30_NONTRN_ADR_Pickup  TM15_RoomsPickup  \
# 2016-08-02           1.818989e-11                    0.00               3.0
# 2016-08-03           2.410000e+02                    4.39               6.0
# 2016-08-04           5.006600e+02                    6.20               4.0
# 2016-08-05           1.103660e+03                   12.97               1.0
# 2016-08-06           1.103660e+03                   14.17               2.0
#
#             TM15_RevPickup  TM15_ADR_Pickup  TM15_TRN_RoomsPickup  \
# 2016-08-02          985.79             2.64                   3.0
# 2016-08-03         1298.66             1.45                   5.0
# 2016-08-04         1120.52             2.22                   2.0
# 2016-08-05          602.02             2.36                  -1.0
# 2016-08-06          855.24             2.75                   0.0
#
#             TM15_TRN_RevPickup  TM15_TRN_ADR_Pickup  TM15_NONTRN_RoomsPickup  \
# 2016-08-02              985.79                 2.93                      0.0
# 2016-08-03             1057.66                 0.86                      1.0
# 2016-08-04              619.86                 2.15                      2.0
# 2016-08-05              101.36                 2.17                      2.0
# 2016-08-06              354.58                 2.34                      2.0
#
#             TM15_NONTRN_RevPickup  TM15_NONTRN_ADR_Pickup  TM05_RoomsPickup  \
# 2016-08-02           1.818989e-11                    0.00               1.0
# 2016-08-03           2.410000e+02                    4.39               9.0
# 2016-08-04           5.006600e+02                    6.20               4.0
# 2016-08-05           5.006600e+02                    4.48               1.0
# 2016-08-06           5.006600e+02                    4.91               2.0
#
#             TM05_RevPickup  TM05_ADR_Pickup  TM05_TRN_RoomsPickup  \
# 2016-08-02          512.25             1.88                   1.0
# 2016-08-03         1753.75             1.09                   8.0
# 2016-08-04          991.50             1.49                   2.0
# 2016-08-05          268.04             0.46                   1.0
# 2016-08-06          497.11             0.68                   2.0
#
#             TM05_TRN_RevPickup  TM05_TRN_ADR_Pickup  TM05_NONTRN_RoomsPickup  \
# 2016-08-02              512.25                 2.11                      0.0
# 2016-08-03             1512.75                 0.35                      1.0
# 2016-08-04              490.84                 1.28                      2.0
# 2016-08-05              268.04                 0.70                      0.0
# 2016-08-06              497.11                 0.67                      0.0
#
#             TM05_NONTRN_RevPickup  TM05_NONTRN_ADR_Pickup  RoomsGapToLYA  \
# 2016-08-02           1.818989e-11                    0.00           -1.0
# 2016-08-03           2.410000e+02                    4.39            0.0
# 2016-08-04           5.006600e+02                    6.20           -1.0
# 2016-08-05           2.182787e-11                    0.00            5.0
# 2016-08-06          -3.637979e-12                    0.00            6.0
#
#             RevGapToLYA  ADR_GapToLYA  TRN_RoomsGapToLYA  TRN_RevGapToLYA  \
# 2016-08-02     -3525.06        -18.43              -27.0         -6103.27
# 2016-08-03     -3828.89        -21.04              -22.0         -5852.58
# 2016-08-04     -4974.25        -26.62              -14.0         -5253.07
# 2016-08-05     -5322.46        -34.40               -4.0         -4482.60
# 2016-08-06     -4861.00        -33.13               -3.0         -3969.91
#
#             TRN_ADR_GapToLYA  NONTRN_RoomsGapToLYA  NONTRN_RevGapToLYA  \
# 2016-08-02            -10.41                  26.0             2578.21
# 2016-08-03            -13.87                  22.0             2023.69
# 2016-08-04            -19.86                  13.0              278.82
# 2016-08-05            -26.94                   9.0             -839.86
# 2016-08-06            -24.10                   9.0             -891.09
#
#             NONTRN_ADR_GapToLYA
# 2016-08-02                -8.02
# 2016-08-03                -7.17
# 2016-08-04                -6.76
# 2016-08-05                -7.46
# 2016-08-06                -9.03

# %%
# self-join df_sim to pull stly stats using the above keys

df_sim = df_sim.merge(df_sim[stly_cols_agg], left_on='stly_id', right_on='id', suffixes=(None, "_STLY"))
df_sim.head(2)
# Out:
#                         id                  stly_id  DOW  RoomsOTB    RevOTB  \
# 0  2017-08-01 - 2017-08-01  2016-08-02 - 2016-08-02  Tue     184.0  35239.14
# 1  2017-08-01 - 2017-08-02  2016-08-02 - 2016-08-03  Wed     185.0  35961.47
#
#    CxlForecast  TRN_RoomsOTB  TRN_RevOTB  TRN_CxlForecast   StayDate     WE  \
# 0         18.0         151.0    29935.72             16.0 2017-08-01  False
# 1         19.0         151.0    30760.93             17.0 2017-08-02  False
#
#       WD STLY_StayDate  DaysUntilArrival  ADR_OTB  SellingPrice   AsOfDate  \
# 0  False    2016-08-02                 0   191.52        204.00 2017-08-01
# 1  False    2016-08-03                 1   194.39        206.75 2017-08-01
#
#   STLY_AsOfDate  RemSupply  Mon  Sat  Sun  Thu  Tue  Wed  NONTRN_RoomsOTB  \
# 0    2016-08-02         21    0    0    0    0    1    0             33.0
# 1    2016-08-02         21    0    0    0    0    0    1             34.0
#
#    NONTRN_RevOTB  NONTRN_ADR_OTB  NONTRN_CxlForecast  TRN_ADR_OTB  \
# 0        5303.42          160.71                 2.0        198.0
# 1        5200.54          152.96                 2.0        204.0
#
#    TM30_RoomsPickup  TM30_RevPickup  TM30_ADR_Pickup  TM30_TRN_RoomsPickup  \
# 0              14.0         3247.96             3.34                  12.0
# 1              11.0         3273.70             6.53                   8.0
#
#    TM30_TRN_RevPickup  TM30_TRN_ADR_Pickup  TM30_NONTRN_RoomsPickup  \
# 0             2708.54                 2.12                      2.0
# 1             2612.78                 7.16                      3.0
#
#    TM30_NONTRN_RevPickup  TM30_NONTRN_ADR_Pickup  TM15_RoomsPickup  \
# 0                 539.42                    7.03               4.0
# 1                 660.92                    6.52               2.0
#
#    TM15_RevPickup  TM15_ADR_Pickup  TM15_TRN_RoomsPickup  TM15_TRN_RevPickup  \
# 0          719.43            -0.26                   4.0              719.43
# 1          753.41             2.00                   2.0              753.41
#
#    TM15_TRN_ADR_Pickup  TM15_NONTRN_RoomsPickup  TM15_NONTRN_RevPickup  \
# 0                -0.75                      0.0          -3.637979e-12
# 1                 2.61                      0.0           0.000000e+00
#
#    TM15_NONTRN_ADR_Pickup  TM05_RoomsPickup  TM05_RevPickup  TM05_ADR_Pickup  \
# 0                     0.0               7.0         1246.40            -0.53
# 1                     0.0               2.0          505.15             0.64
#
#    TM05_TRN_RoomsPickup  TM05_TRN_RevPickup  TM05_TRN_ADR_Pickup  \
# 0                   7.0             1246.40                -1.23
# 1                   2.0              505.15                 0.94
#
#    TM05_NONTRN_RoomsPickup  TM05_NONTRN_RevPickup  TM05_NONTRN_ADR_Pickup  \
# 0                      0.0          -3.637979e-12                     0.0
# 1                      0.0          -3.637979e-12                     0.0
#
#    RoomsGapToLYA  RevGapToLYA  ADR_GapToLYA  TRN_RoomsGapToLYA  \
# 0           -1.0     -4128.25        -21.52                8.0
# 1           -3.0     -4300.85        -20.43                8.0
#
#    TRN_RevGapToLYA  TRN_ADR_GapToLYA  NONTRN_RoomsGapToLYA  \
# 0         -2106.67            -22.97                  -9.0
# 1         -2423.05            -25.77                 -11.0
#
#    NONTRN_RevGapToLYA  NONTRN_ADR_GapToLYA                  id_STLY  \
# 0            -2021.58                 1.45  2016-08-02 - 2016-08-02
# 1            -1877.80                 5.34  2016-08-02 - 2016-08-03
#
#    DaysUntilArrival_STLY  RoomsOTB_STLY  ADR_OTB_STLY  RevOTB_STLY  \
# 0                      0          183.0        170.00     31110.89
# 1                      1          182.0        173.96     31660.62
#
#    CxlForecast_STLY  RemSupply_STLY  SellingPrice_STLY  TRN_RoomsOTB_STLY  \
# 0              30.0              34             178.09              159.0
# 1              35.0              40             181.69              159.0
#
#    TRN_ADR_OTB_STLY  TRN_RevOTB_STLY  TRN_CxlForecast_STLY  \
# 0             175.0         27829.05                  28.0
# 1             178.0         28337.88                  31.0
#
#    NONTRN_RoomsOTB_STLY  NONTRN_ADR_OTB_STLY  NONTRN_RevOTB_STLY  \
# 0                  24.0               136.74             3281.84
# 1                  23.0               144.47             3322.74
#
#    NONTRN_CxlForecast_STLY  TM30_RoomsPickup_STLY  TM30_ADR_Pickup_STLY  \
# 0                      2.0                    3.0                  4.00
# 1                      4.0                    3.0                  3.47
#
#    TM30_RevPickup_STLY  TM30_TRN_RoomsPickup_STLY  TM30_TRN_ADR_Pickup_STLY  \
# 0              1230.63                        3.0                      4.50
# 1              1143.03                        2.0                      3.25
#
#    TM30_TRN_RevPickup_STLY  TM30_NONTRN_RoomsPickup_STLY  \
# 0                  1230.63                           0.0
# 1                   902.03                           1.0
#
#    TM30_NONTRN_ADR_Pickup_STLY  TM30_NONTRN_RevPickup_STLY  \
# 0                         0.00                1.818989e-11
# 1                         4.39                2.410000e+02
#
#    TM15_RoomsPickup_STLY  TM15_ADR_Pickup_STLY  TM15_RevPickup_STLY  \
# 0                    3.0                  2.64               985.79
# 1                    6.0                  1.45              1298.66
#
#    TM15_TRN_RoomsPickup_STLY  TM15_TRN_ADR_Pickup_STLY  \
# 0                        3.0                      2.93
# 1                        5.0                      0.86
#
#    TM15_TRN_RevPickup_STLY  TM15_NONTRN_RoomsPickup_STLY  \
# 0                   985.79                           0.0
# 1                  1057.66                           1.0
#
#    TM15_NONTRN_ADR_Pickup_STLY  TM15_NONTRN_RevPickup_STLY  \
# 0                         0.00                1.818989e-11
# 1                         4.39                2.410000e+02
#
#    TM05_RoomsPickup_STLY  TM05_ADR_Pickup_STLY  TM05_RevPickup_STLY  \
# 0                    1.0                  1.88               512.25
# 1                    9.0                  1.09              1753.75
#
#    TM05_TRN_RoomsPickup_STLY  TM05_TRN_ADR_Pickup_STLY  \
# 0                        1.0                      2.11
# 1                        8.0                      0.35
#
#    TM05_TRN_RevPickup_STLY  TM05_NONTRN_RoomsPickup_STLY  \
# 0                   512.25                           0.0
# 1                  1512.75                           1.0
#
#    TM05_NONTRN_ADR_Pickup_STLY  TM05_NONTRN_RevPickup_STLY
# 0                         0.00                1.818989e-11
# 1                         4.39                2.410000e+02
