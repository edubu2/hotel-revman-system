# %% [markdown]
# import pandas as pd
# import numpy as np
# import datetime

# %%
pd.options.display.max_rows = 60
pd.options.display.max_columns = 60

# %%
h1_res = pd.read_pickle("pickle/h1_res.pick")
h2_res = pd.read_pickle("pickle/h2_res.pick")
h1_dbd = pd.read_pickle("pickle/h1_dbd.pick")
h2_dbd = pd.read_pickle("pickle/h2_dbd.pick")

# %%
h1_dbd.shape
# Out:
# (793, 21)

# %%
h1_res.head(10)
# Out:
#    ResNum  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0       0           0       342             2015             July
# 1       1           0       737             2015             July
# 2       2           0         7             2015             July
# 3       3           0        13             2015             July
# 4       4           0        14             2015             July
# 5       5           0        14             2015             July
# 6       6           0         0             2015             July
# 7       7           0         9             2015             July
# 8       8           1        85             2015             July
# 9       9           1        75             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# ...

# %%
h1_dbd.head(10)
# Out:
#             DOW   Occ  RoomsSold     ADR   RoomRev  RevPAR  Trn_RoomsSold  \
# 2015-07-01  Wed  0.19       36.0   93.25   3356.83   17.95           30.0
# 2015-07-02  Thu  0.34       64.0   97.68   6251.33   33.43           43.0
# 2015-07-03  Fri  0.43       81.0   99.41   8052.35   43.06           54.0
# 2015-07-04  Sat  0.58      108.0   96.98  10473.47   56.01           71.0
# 2015-07-05  Sun  0.65      122.0   97.56  11901.72   63.65           79.0
# 2015-07-06  Mon  0.76      142.0  101.05  14349.04   76.73           96.0
# 2015-07-07  Tue  0.82      153.0  103.08  15771.44   84.34          103.0
# 2015-07-08  Wed  0.84      157.0  104.77  16448.71   87.96          108.0
# 2015-07-09  Thu  0.90      168.0  105.89  17790.31   95.14          114.0
# 2015-07-10  Fri  0.95      177.0  108.87  19269.19  103.04          120.0
#
#             Trn_ADR  Trn_RoomRev  Grp_RoomsSold  Grp_ADR  Grp_RoomRev  \
# 2015-07-01    95.91      2877.25            0.0      0.0          0.0
# ...

# %% [markdown]
# ## Vinny 1-1 3/4 Notes
#
# * Possible model for only 750 days (only ~365 for training set?)
#     *
# *
# *
#
# 3 models
# * df_res
#     * cxl forecast
#
# * df_dbd (AS OF GIVEN DATE)
#     * projected occ
#     * rate recommendations
#
# Features
# * Rooms OTB at this time
# * Rooms OTB STLY (by day of week)
# * Recent trends (bookings) compared to same trend STLY
# * Pace
# * How many rooms left to sell
#     * used as feature for proj. occ model
#
# Rate Recc model
# * uses projected occ,
# * time series model - lstm neural net (long shorttail model) - good for time series
#     * lstm is data-hungry (try but may not have enough data)

# %% [markdown]
# ## Vinny 1-1 3/10 Notes
#
# **LSTM Model?**
# * run simpler model first
#     * Lr, RF
# * create a GENR price
# * add differentials based on ADR by booked room type
#
# * try different prices until occ & ADr starts to make sense
# * calculate rev at each price point based on remaining demand @ that price
#     * record this for each price level & compare
