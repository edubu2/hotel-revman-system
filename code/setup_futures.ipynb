# %% [markdown]
# # Setup Future DBD DataFrames
#
# This DataFrame will be used for predicting demand and ultimately recommending rates.
#
# This notebooks makes use of the `generate_hotel_dfs` and `model_cancellations` functions found in `utils.py`.

# %%
import pandas as pd
import numpy as np
from utils import res_to_dbd, add_dbd_columns

# %%
pd.options.display.max_rows = 60
pd.options.display.max_columns = 70

# %% [markdown]
# ## Hotel Capacities
#
# H1: 187
#
# H2: 226

# %%
h1_futures = pd.read_pickle("pickle/h1_future_res.pick")
h2_futures = pd.read_pickle("pickle/h2_future_res.pick")

# %%
h1_futures
# Out:
#        LeadTime  LOS  StaysInWeekendNights  StaysInWeekNights     ADR  \
# 12815       240   16                     5                 11  183.05
# 12816       236   16                     5                 11  182.92
# 12859       202   14                     4                 10  158.63
# 12874       200   15                     4                 11  172.20
# 12911       163   14                     4                 10  180.00
# ...         ...  ...                   ...                ...     ...
# 40055       212   10                     2                  8   89.75
# 40056       169   11                     2                  9  202.27
# 40057       204   14                     4                 10  153.57
# 40058       211   14                     4                 10  112.80
# 40059       161   14                     4                 10   99.06
#
#        NumPeople  Adults  Children  Babies  TotalOfSpecialRequests  \
# 12815          2       2         0       0                       0
# 12816          2       2         0       0                       0
# 12859          3       2         1       0                       0
# 12874          2       2         0       0                       1
# 12911          2       2         0       0                       2
# ...          ...     ...       ...     ...                     ...
# 40055          3       2         1       0                       0
# 40056          2       2         0       0                       1
# 40057          2       2         0       0                       3
# 40058          2       2         0       0                       1
# 40059          2       2         0       0                       0
#
#        PreviousBookings  PreviousCancellations  PreviousBookingsNotCanceled  \
# 12815                 0                      0                            0
# 12816                 0                      0                            0
# 12859                 0                      0                            0
# 12874                 0                      0                            0
# 12911                 0                      0                            0
# ...                 ...                    ...                          ...
# 40055                 0                      0                            0
# 40056                 0                      0                            0
# 40057                 0                      0                            0
# 40058                 0                      0                            0
# 40059                 0                      0                            0
#
#        BookingChanges  DaysInWaitingList  RequiredCarParkingSpaces  \
# 12815               0                  0                         0
# 12816               0                  0                         0
# 12859               0                  0                         0
# 12874               0                  0                         0
# 12911               0                  0                         0
# ...               ...                ...                       ...
# 40055               1                  0                         0
# 40056               0                  0                         0
# 40057               0                  0                         0
# 40058               0                  0                         0
# 40059               0                  0                         0
#
#        IsRepeatedGuest  AgencyBooking  CompanyListed  CT_is_grp  CT_is_trn  \
# 12815                0           True          False          0          1
# 12816                0           True          False          0          1
# 12859                0           True          False          0          1
# 12874                0           True          False          0          1
# 12911                0           True          False          0          1
# ...                ...            ...            ...        ...        ...
# 40055                0           True          False          0          1
# 40056                0           True          False          0          0
# 40057                0           True          False          0          1
# 40058                0           True          False          0          0
# 40059                0           True          False          0          1
#
#        CT_is_trnP  RS_No-Show  MS_Corporate  MS_Direct  MS_Groups  \
# 12815           0           0             0          0          0
# 12816           0           0             0          0          0
# 12859           0           0             0          0          0
# 12874           0           0             0          0          0
# 12911           0           0             0          0          0
# ...           ...         ...           ...        ...        ...
# 40055           0           0             0          0          0
# 40056           1           0             0          1          0
# 40057           0           0             0          1          0
# 40058           0           0             0          0          0
# 40059           0           0             0          0          0
#
#        MS_Offline TA/TO  MS_Online TA  DC_Direct  DC_TA/TO  DC_Undefined  \
# 12815                 0             1          0         1             0
# 12816                 0             1          0         1             0
# 12859                 1             0          0         1             0
# 12874                 0             1          0         1             0
# 12911                 0             1          0         1             0
# ...                 ...           ...        ...       ...           ...
# 40055                 1             0          0         1             0
# 40056                 0             0          1         0             0
# 40057                 0             0          1         0             0
# 40058                 1             0          0         1             0
# 40059                 1             0          0         1             0
#
#        FROM_PRT  FROM_GBR  FROM_ESP  FROM_IRL  FROM_FRA  FROM_DEU  FROM_CN  \
# 12815     False     False     False     False     False     False    False
# 12816      True     False     False     False     False     False    False
# 12859      True     False     False     False     False     False    False
# 12874      True     False     False     False     False     False    False
# 12911      True     False     False     False     False     False    False
# ...         ...       ...       ...       ...       ...       ...      ...
# 40055     False      True     False     False     False     False    False
# 40056     False     False     False      True     False     False    False
# 40057     False     False     False      True     False     False    False
# 40058     False      True     False     False     False     False    False
# 40059     False     False     False     False     False      True    False
#
#        FROM_NLD  FROM_USA  FROM_ITA  FROM_other  DT_NonRefundable  \
# 12815     False     False     False        True                 0
# 12816     False     False     False       False                 0
# 12859     False     False     False       False                 0
# 12874     False     False     False       False                 0
# 12911     False     False     False       False                 0
# ...         ...       ...       ...         ...               ...
# 40055     False     False     False       False                 0
# 40056     False     False     False       False                 0
# 40057     False     False     False       False                 0
# 40058     False     False     False       False                 0
# 40059     False     False     False       False                 0
#
#        DT_Refundable  MEAL_Undefined  MEAL_HB  MEAL_FB  cxl_proba  will_cancel
# 12815              0               0        1        0   0.821473         True
# 12816              0               0        1        0   0.954606         True
# 12859              0               0        0        0   0.767688         True
# 12874              0               0        0        0   0.790812         True
# 12911              0               0        0        0   0.910071         True
# ...              ...             ...      ...      ...        ...          ...
# 40055              0               0        0        0   0.000651        False
# 40056              0               0        0        0   0.090667        False
# 40057              0               0        0        0   0.087720        False
# 40058              0               0        1        0   0.000492        False
# 40059              0               0        1        0   0.002840        False
#
# [1765 rows x 49 columns]

# %%
h1_futures.head(3)
# Out:
#        LeadTime  LOS  StaysInWeekendNights  StaysInWeekNights     ADR  \
# 12815       240   16                     5                 11  183.05
# 12816       236   16                     5                 11  182.92
# 12859       202   14                     4                 10  158.63
#
#        NumPeople  Adults  Children  Babies  TotalOfSpecialRequests  \
# 12815          2       2         0       0                       0
# 12816          2       2         0       0                       0
# 12859          3       2         1       0                       0
#
#        PreviousBookings  PreviousCancellations  PreviousBookingsNotCanceled  \
# 12815                 0                      0                            0
# 12816                 0                      0                            0
# 12859                 0                      0                            0
#
#        BookingChanges  DaysInWaitingList  RequiredCarParkingSpaces  \
# 12815               0                  0                         0
# 12816               0                  0                         0
# 12859               0                  0                         0
#
#        IsRepeatedGuest  AgencyBooking  CompanyListed  CT_is_grp  CT_is_trn  \
# 12815                0           True          False          0          1
# 12816                0           True          False          0          1
# 12859                0           True          False          0          1
#
#        CT_is_trnP  RS_No-Show  MS_Corporate  MS_Direct  MS_Groups  \
# 12815           0           0             0          0          0
# 12816           0           0             0          0          0
# 12859           0           0             0          0          0
#
#        MS_Offline TA/TO  MS_Online TA  DC_Direct  DC_TA/TO  DC_Undefined  \
# 12815                 0             1          0         1             0
# 12816                 0             1          0         1             0
# 12859                 1             0          0         1             0
#
#        FROM_PRT  FROM_GBR  FROM_ESP  FROM_IRL  FROM_FRA  FROM_DEU  FROM_CN  \
# 12815     False     False     False     False     False     False    False
# 12816      True     False     False     False     False     False    False
# 12859      True     False     False     False     False     False    False
#
#        FROM_NLD  FROM_USA  FROM_ITA  FROM_other  DT_NonRefundable  \
# 12815     False     False     False        True                 0
# 12816     False     False     False       False                 0
# 12859     False     False     False       False                 0
#
#        DT_Refundable  MEAL_Undefined  MEAL_HB  MEAL_FB  cxl_proba  will_cancel
# 12815              0               0        1        0   0.821473         True
# 12816              0               0        1        0   0.954606         True
# 12859              0               0        0        0   0.767688         True

# %%
h1_future_dbd = res_to_dbd(h1_futures, first_date="2017-08-01")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IsCanceled'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-f5db23500c02> in <module>
# ----> 1 h1_future_dbd = res_to_dbd(h1_futures, first_date="2017-08-01")
#
# ~/metis/projects/hotel-revman-system/code/utils.py in res_to_dbd(df_res, first_date)
#     147     guests that arrived previously and are staying multiple nights.
#     148     """
# --> 149     mask = df_res["IsCanceled"] == 0
#     150     df_dates = df_res[mask].copy()
#     151
#
# ~/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'IsCanceled'

# %%
h1_future_dbd

# %%
h1_future_dbd = add_dbd_columns(h1_future_dbd, capacity=187)
