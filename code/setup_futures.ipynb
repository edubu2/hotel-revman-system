# %% [markdown]
# # Setup Future DBD DataFrames
#
# This DataFrame will be used for predicting demand and ultimately recommending rates.
#
# This notebooks makes use of the `generate_hotel_dfs` and `model_cancellations` functions found in `utils.py`.

# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = 60
pd.options.display.max_columns = 70

# %%
h1_futures = pd.read_pickle("pickle/h1_futures.pick")
h2_futures = pd.read_pickle("pickle/h2_futures.pick")

# %%
h1_futures.head(3)
# Out:
#        LeadTime  LOS  StaysInWeekendNights  StaysInWeekNights     ADR  \
# 12815       240   16                     5                 11  183.05
# 12816       236   16                     5                 11  182.92
# 12859       202   14                     4                 10  158.63
#
#        NumPeople  Adults  Children  Babies  TotalOfSpecialRequests  \
# 12815          2       2         0       0                       0
# 12816          2       2         0       0                       0
# 12859          3       2         1       0                       0
#
#        PreviousBookings  PreviousCancellations  PreviousBookingsNotCanceled  \
# 12815                 0                      0                            0
# 12816                 0                      0                            0
# 12859                 0                      0                            0
#
#        BookingChanges  DaysInWaitingList  RequiredCarParkingSpaces  \
# 12815               0                  0                         0
# 12816               0                  0                         0
# 12859               0                  0                         0
#
#        IsRepeatedGuest  AgencyBooking  CompanyListed  CT_is_grp  CT_is_trn  \
# 12815                0           True          False          0          1
# 12816                0           True          False          0          1
# 12859                0           True          False          0          1
#
#        CT_is_trnP  RS_No-Show  MS_Corporate  MS_Direct  MS_Groups  \
# 12815           0           0             0          0          0
# 12816           0           0             0          0          0
# 12859           0           0             0          0          0
#
#        MS_Offline TA/TO  MS_Online TA  DC_Direct  DC_TA/TO  DC_Undefined  \
# 12815                 0             1          0         1             0
# 12816                 0             1          0         1             0
# 12859                 1             0          0         1             0
#
#        FROM_PRT  FROM_GBR  FROM_ESP  FROM_IRL  FROM_FRA  FROM_DEU  FROM_CN  \
# 12815     False     False     False     False     False     False    False
# 12816      True     False     False     False     False     False    False
# 12859      True     False     False     False     False     False    False
#
#        FROM_NLD  FROM_USA  FROM_ITA  FROM_other  DT_NonRefundable  \
# 12815     False     False     False        True                 0
# 12816     False     False     False       False                 0
# 12859     False     False     False       False                 0
#
#        DT_Refundable  MEAL_Undefined  MEAL_HB  MEAL_FB will_cancel
# 12815              0               0        1        0         NaN
# 12816              0               0        1        0         NaN
# 12859              0               0        0        0         NaN
